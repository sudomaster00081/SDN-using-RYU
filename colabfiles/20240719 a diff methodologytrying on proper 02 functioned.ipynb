# %%
# !pip install minisom
# Out:
# Collecting minisom
#   Downloading MiniSom-2.3.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: minisom
#   Building wheel for minisom (setup.py) ... done
#   Created wheel for minisom: filename=MiniSom-2.3.2-py3-none-any.whl size=10650 sha256=4fc1c664903d5637d48c785a5ff79844eef60c077ca7987040f2ba240e6f7be5
#   Stored in directory: /root/.cache/pip/wheels/b4/f6/8a/9daf8831901c3e3805775633404248f10663d1c80b7e5a1314
# Successfully built minisom
# Installing collected packages: minisom
# Successfully installed minisom-2.3.2

# %% [markdown]
# # import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from minisom import MiniSom
from sklearn.neighbors import KNeighborsClassifier
import pickle
# Evaluate performance
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report

from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestClassifier

import time

# Methodologys
from sklearn import preprocessing

from tqdm import tqdm

from sklearn.metrics import roc_auc_score

from sklearn.metrics import matthews_corrcoef

from tabulate import tabulate

import random
from itertools import product

# %% [markdown]
# ##urls

# %% [markdown]
# ## normalize_with_tanh_estimator

# %%
# Define the function for normalization using tanh-estimator method, excluding specified columns
def normalize_with_tanh_estimator(data, mean_std_dict):
    normalized_data = pd.DataFrame()
    for col in data.columns:
          mu, sigma = mean_std_dict[col]
          normalized_col = 0.5 * (np.tanh(0.1 * ((data[col] - mu) / sigma)) + 1)
          normalized_data[col] = normalized_col

    return normalized_data

# %% [markdown]
# ## Distance calculation

# %%
# Function to calculate distance between input sample V and reference point G
def calculate_distance(v, g, comments):
  """Calculates the distance between two points using different methods.

  Args:
    v: The first point.
    g: The second point.
    comment: A string indicating the desired distance method.

  Returns:
    The calculated distance.

  Raises:
    ValueError: If an unsupported distance method is specified.
  """

  if "euclidean" in comments:
    return np.linalg.norm(v - g)
  elif "manhattan" in comments:
    return np.sum(np.abs(v - g))
  elif "chebyshev" in comments:
    return np.max(np.abs(v - g))
  elif "cosine" in comments:
    # Ensure v and g are normalized for cosine distance
    v_norm = v / np.linalg.norm(v)
    g_norm = g / np.linalg.norm(g)
    return 1 - np.dot(v_norm, g_norm)
  else:
    raise ValueError(f"Unsupported distance method: {comments}")

# %% [markdown]
# ## SOM_Prediction

# %%
# Function to classify input sample as attack or normal and update y_pred array
def som_prediction_normal(sample, d_threshold, sigma, g):
  y_pred = []
  for sam in sample:
    distance_to_g = calculate_distance(sam, g)
    # print("distance_to_g", distance_to_g)
    p_d_greater_than_x = 1 - np.exp(- (distance_to_g / sigma)**2)  # Cumulative distribution function
    is_attack = distance_to_g > d_threshold or p_d_greater_than_x > 0.6  # You can adjust the threshold as needed
    y_pred.append(1 if is_attack else 0)

  return y_pred



# Function to classify input sample as attack or normal and update y_pred array

# def som_prediction(sample, d_threshold, g): # without sigma
#   y_pred = []
#   for sam in sample:
#     distance_to_g = calculate_distance(sam, g)
#     # print("distance_to_g", distance_to_g)
#     # p_d_greater_than_x = 1 - np.exp(- (distance_to_g / sigma)**2)  # Cumulative distribution function
#     is_attack = distance_to_g > d_threshold  # You can adjust the threshold as needed
#     y_pred.append(1 if is_attack else 0)

#   return y_pred


# Function to classify input sample as attack or normal and update y_pred array

def som_prediction(sample, d_threshold,sigma, g, comments): #with digma
  y_pred = []
  for sam in sample:
    distance_to_g = calculate_distance(sam, g, comments)
    # print("distance_to_g", distance_to_g)
    # p_d_greater_than_x = 1 - np.exp(- (distance_to_g / sigma)**2)  # Cumulative distribution function
    # print("distance to g and d_threshold", distance_to_g, d_threshold)
    is_attack = distance_to_g > d_threshold  # You can adjust the threshold as needed
    # print("is attack value", is_attack)
    y_pred.append(1 if is_attack else 0)

  return y_pred

# %% [markdown]
# ## Genetic algorithm

# %%
def selection(population, fitness_scores):
  # # Roulette wheel selection
  # fitness_sum = sum(fitness_scores)
  # probabilities = [score / fitness_sum for score in fitness_scores]
  # parents = []
  # for _ in range(len(population)):
  #   parent = random.choices(population, weights=probabilities)[0]
  #   parents.append(parent)
  # return parents
  # # Assign ranks to individuals based on fitness scores
  #   ranked_population = sorted(population, key=lambda x: fitness_scores[population.index(x)], reverse=True)
  #   ranks = list(range(1, len(population) + 1))  # Assign ranks from 1 to N

  #   # Calculate selection probabilities based on ranks
  #   rank_sum = sum(ranks)
  #   probabilities = [rank / rank_sum for rank in ranks]

  #   # Select parents based on rank probabilities
  #   parents = []
  #   for _ in range(len(population)):
  #       parent = random.choices(ranked_population, weights=probabilities)[0]
  #       parents.append(parent)

  #   return parents
  tournament_size = 10  # Adjust the tournament size as needed
  selected_parents = []
  population_size = len(population)

  for _ in range(population_size):
        # Randomly select individuals for the tournament
        tournament = random.sample(list(zip(population, fitness_scores)), tournament_size)

        # Find the individual with the highest fitness in the tournament
        winner = max(tournament, key=lambda x: x[1])[0]

        # Add the winner to the selected parents
        selected_parents.append(winner)

  return selected_parents

def crossover(parents, crossover_rate):
  offspring = []
  for i in range(0, len(parents), 2):
    if random.random() < crossover_rate:
      parent1, parent2 = parents[i], parents[i+1]
      child1 = (parent1 + parent2) / 2
      child2 = (parent1 - parent2) / 2
      offspring.extend([child1, child2])
    else:
      offspring.extend([parents[i], parents[i+1]])
  return offspring

def mutation(offspring, mutation_rate):
  for i in range(len(offspring)):
    if random.random() < mutation_rate:
      offspring[i] += random.uniform(-0.1, 0.1)  # Adjust mutation step
  return offspring

def replace(population, offspring):
  return offspring

def genetic_algorithm(df, num_generations, population_size, crossover_rate, mutation_rate, test_X,test_y,g, comments):
  # Initialization
  if 'cosine' in comments:
    d_threshold_min = 0
    d_threshold_max = 2

  else:
    d_threshold_min = 0.001
    d_threshold_max = 50
  population = [random.uniform(d_threshold_min, d_threshold_max) for _ in range(population_size)]
  fitness_scores = [eval_function(individual, test_X, test_y,g, comments) for individual in population]
  generation_val =[]
  for generation in tqdm(range(num_generations)):
  # for generation in range(num_generations):
    parents = selection(population, fitness_scores)
    offspring = crossover(parents, crossover_rate)
    offspring = mutation(offspring, mutation_rate)
    population = replace(population, offspring)
    fitness_scores = [eval_function(individual, test_X, test_y,g, comments) for individual in population]
    generation_val.append(fitness_scores)

  #plot the fitness score per iteration as graph
  plt.plot(generation_val)
  plt.xlabel('Generation')
  plt.ylabel('Fitness Score')
  plt.title('Fitness Score per Generation')
  plt.show()

  best_index = np.argmax(fitness_scores)
  best_individual = population[best_index]
  return best_individual

def eval_function(individual, test_X, test_y,g, comments):
  # print("Individual", individual)
  sigma = 1
  # Calculate fitness based on individual's d_threshold
  sigma, d_threshold, accuracy, fdr, attack_as_normal, normal_as_attack, attack_as_attack, normal_as_normal, rocauc, mcc, eval = get_details_for_som(test_X, test_y, individual, sigma, g, comments)
  return eval

# %% [markdown]
# ## CF Matrix

# %%
def true_vs_predicted(y_true, y_pred):

  # Compute confusion matrix
  cm = confusion_matrix(y_true, y_pred)

  # Extract counts from confusion matrix
  attack_as_normal = cm[1, 0]
  normal_as_attack = cm[0, 1]
  attack_as_attack = cm[1, 1]
  normal_as_normal = cm[0, 0]

  # Print the results
  print("attack (1) but predicted as normal =", attack_as_normal)
  print("normal (0) but predicted as attack =", normal_as_attack)
  print("attack (1) predicted as attack =", attack_as_attack)
  print("normal (0) predicted as normal =", normal_as_normal)

def true_vs_predicted_with_return(y_true, y_pred):

  # Compute confusion matrix
  cm = confusion_matrix(y_true, y_pred)

  # Extract counts from confusion matrix
  try:
    attack_as_normal = cm[1, 0]
  except:
    attack_as_normal = None
  try:
    normal_as_attack = cm[0, 1]
  except:
    normal_as_attack = None
  try:
    attack_as_attack = cm[1, 1]
  except:
    attack_as_attack = None
  try:
    normal_as_normal = cm[0, 0]
  except:
    normal_as_normal = None


  return attack_as_normal, normal_as_attack, attack_as_attack, normal_as_normal

def evaluate_true_and_predicted(test_y, y_pred):

  true_vs_predicted(test_y, y_pred)
  print("\n", classification_report(test_y,y_pred, zero_division=1, output_dict=True))
  print("Accuracy : ",accuracy_score(test_y, y_pred))

  return

def evaluate_true_and_predicted_with_return(com,test_y, y_pred):

  attack_as_normal, normal_as_attack, attack_as_attack, normal_as_normal = true_vs_predicted_with_return(test_y, y_pred)
  # Generate classification report
  precision_recall = classification_report(test_y, y_pred, output_dict=True, zero_division=1)
  precision_ddos = precision_recall['1']  # Assuming '1' represents DDoS class

  fdr = (1 - precision_ddos['precision'])*100
  # Calculate False Detection Rate (FDR)
  print("\n", classification_report(test_y,y_pred, zero_division=1))
  accuracy = (accuracy_score(test_y, y_pred))*100
  print(f"\nAccuracy : {accuracy} % ")
  print(f"False Detection Rate (FDR): {fdr:.2f}%")
  # result = [com,accuracy, fdr, attack_as_normal, normal_as_attack, attack_as_attack, normal_as_normal]
  # Assuming com, accuracy, fdr, etc. are lists or arrays of the same length
  result = [com, accuracy, fdr, attack_as_normal, normal_as_attack, attack_as_attack, normal_as_normal]
  columns = ['com', 'accuracy', 'fdr', 'attack_as_normal', 'normal_as_attack', 'attack_as_attack', 'normal_as_normal']

  # Create a dictionary
  data_dict = {col: [val] for col, val in zip(columns, result)}

  # Create the DataFrame
  # result_df = pd.DataFrame(data_dict)
  print(result)
  print("\n",com)
  # resultant_columns = ['accuracy', 'attack_as_normal', 'normal_as_attack', 'attack_as_attack', 'normal_as_normal']
  # resultant_df = pd.DataFrame(result,columns=resultant_columns)
  # result_df = pd.DataFrame(result)
  # result_df.columns = ['comment', 'accuracy', 'FDR', 'attack_as_normal', 'normal_as_attack', 'attack_as_attack', 'normal_as_normal']
  return data_dict

# %% [markdown]
# ## with_som_and_rf

# %%
def with_som_and_rf(df, com, bandflag):

  if bandflag == 1:
    # Check if the column exists
    column_to_drop = 'bandwidth'
    if column_to_drop in df.columns:
        # Drop the column
        df.drop(columns=[column_to_drop], inplace=True)
        print(f"\n'{column_to_drop}' column dropped.")
    else:
        print(f"\nColumn '{column_to_drop}' not found in the DataFrame.")


  som_d_threshold = 0.13309999999999966  # Predefined distance threshold
  som_sigma =  0.139099999999999  # Probability threshold


  # Define the columns to exclude from normalization
  exclude_cols = ['label']  # Add more columns here if needed
  # Calculate and store the mean and standard deviation for each dimension, excluding specified columns
  mean_std_dict = {}
  for col in df.columns:
      if col not in exclude_cols:
          mean_std_dict[col] = (df[col].mean(), df[col].std())

  # Normalize the dataset using tanh-estimator method, excluding specified columns
  # df_normalized = normalize_with_tanh_estimator(df, mean_std_dict)
  df_normalized = df


  # Get trained som model
  g = get_model_som(df_normalized)

  #for test
  test_X = df_normalized.iloc[:, :-1].values
  test_y = df_normalized.iloc[:, -1].values

  X_train, X_test, y_train, y_test = train_test_split(test_X, test_y, test_size=0.3, random_state=42)

  rf_model = get_model_rf(X_train, y_train)

  som_start_time = time.time()
  y_pred_som = som_prediction(test_X, som_d_threshold, som_sigma, g)
  som_end_time = time.time()
  som_time = som_end_time - som_start_time
  print(f"SOM time: {som_time} seconds")

  rf_start_time = time.time()
  y_pred_rf = rf_model.predict(test_X)
  rf_end_time = time.time()
  rf_time = rf_end_time - rf_start_time
  print(f"RF time: {rf_time} seconds")


  combined_start_time = time.time()
  y_pred_som_and_rf = som_and_rf_prediction_from_array(test_X, som_d_threshold, som_sigma, g, rf_model)
  combined_end_time = time.time()
  combined_time = combined_end_time - combined_start_time
  print(f"Combined time: {combined_time} seconds")


  #### evaluation
  print("____"*80)
  print("\n For SOM Model")
  print("--"*40)
  som_values = evaluate_true_and_predicted_with_return(com,test_y, y_pred_som)

  print("\n For RF Model")
  print("--"*40)
  rf_values = evaluate_true_and_predicted_with_return(com,test_y, y_pred_rf)

  print("\n For SOM and RF Model")
  print("--"*40)
  y_pred_som_and_rf_values = evaluate_true_and_predicted_with_return(com,test_y, y_pred_som_and_rf)
  result = [som_values, rf_values, y_pred_som_and_rf_values]
  print("____"*80)
  # print(result)
  # resultant_columns = ['som_values', 'rf_values', 'y_pred_som_and_rf_values']
  # resultant_df = pd.DataFrame(result,columns=resultant_columns)
  return result

# %% [markdown]
# ## get_details_for_som

# %%
def get_details_for_som(test_X, test_y, d_threshold, sigma, g, comments):

  y_pred_som = som_prediction(test_X, d_threshold, sigma, g,comments)

  accuracy = accuracy_score(test_y, y_pred_som)
  attack_as_normal, normal_as_attack, attack_as_attack, normal_as_normal = true_vs_predicted_with_return(test_y, y_pred_som)
  # fdr = (1 - attack_as_attack / (attack_as_attack + normal_as_attack)) * 100
  denominator = attack_as_attack + normal_as_attack
  if denominator == 0:
    fdr = 0  # Setting FDR to zero when denominator is zero
  else:
    fdr = (1 - attack_as_attack / denominator) * 100

  # calculate rocauc
  rocauc = roc_auc_score(test_y, y_pred_som)
  mcc = matthews_corrcoef(test_y, y_pred_som)

  eval = rocauc + mcc

  return sigma, d_threshold, accuracy, fdr, attack_as_normal, normal_as_attack, attack_as_attack, normal_as_normal, rocauc, mcc, eval

# %% [markdown]
# ## som_with_varying_sigma_and_d_threshold

# %%
def som_with_varying_sigma_and_d_threshold(df, visual =1):

  df = df
  sigma_min = 0.001
  sigma_max = 0.5
  sigma_step = 0.01
  d_threshold_min = 0.001
  d_threshold_max = 0.5
  d_threshold_step = 0.01


  # Generate arrays of varying values for sigma and d_threshold
  sigma_values = np.arange(sigma_min, sigma_max + sigma_step, sigma_step)
  d_threshold_values = np.arange(d_threshold_min, d_threshold_max + d_threshold_step, d_threshold_step)
  max = len(sigma_values)*len(d_threshold_values)
  i = 1
  # Define the columns to exclude from normalization
  exclude_cols = ['label']  # Add more columns here if needed
  # Calculate and store the mean and standard deviation for each dimension, excluding specified columns
  mean_std_dict = {}
  for col in df.columns:
      if col not in exclude_cols:
          mean_std_dict[col] = (df[col].mean(), df[col].std())

  # Normalize the dataset using tanh-estimator method, excluding specified columns
  # df_normalized = normalize_with_tanh_estimator(df, mean_std_dict)
  df_normalized = normalize_df(df, mean_std_dict)
  # df_normalized = df


  # Get trained som model
  g = get_model_som(df_normalized)

  #for test
  test_X = df_normalized.iloc[:, :-1].values
  test_y = df_normalized.iloc[:, -1].values

  result = []
  for sigma in sigma_values:
    for d_threshold in d_threshold_values:
      print(f"\r{i/max * 100}---  {max}")
      result.append(get_details_for_som(test_X, test_y, d_threshold, sigma, g))
      i=i+1




  resultant_columns = ['sigma', 'd_threshold', 'accuracy', 'FDR', 'attack_as_normal', 'normal_as_attack', 'attack_as_attack', 'normal_as_normal']
  resultant_df = pd.DataFrame(result,columns=resultant_columns)
  return resultant_df

# %%
def avg_time_per_prediction(dataset_size, total_time):
  return(total_time/dataset_size * 1000)

# %% [markdown]
# ## Pooling

# %%
def max_pool(som_map, pool_size):
  """
  Performs max pooling on a SOM map.

  Args:
    som_map: The SOM map as a NumPy array.
    pool_size: The size of the pooling region.

  Returns:
    The pooled SOM map.
  """

  h, w, c = som_map.shape  # Assuming a 3D SOM map

  out_h = h // pool_size
  out_w = w // pool_size

  pooled_map = np.zeros((out_h, out_w, c))

  for i in range(out_h):
    for j in range(out_w):
      for k in range(c):
        pooled_map[i, j, k] = np.max(som_map[i * pool_size: (i + 1) * pool_size,
                                           j * pool_size: (j + 1) * pool_size, k])

  return pooled_map

def average_pool(som_map, pool_size):
  """
  Performs average pooling on a SOM map.

  Args:
    som_map: The SOM map as a NumPy array.
    pool_size: The size of the pooling region.

  Returns:
    The pooled SOM map.
  """

  h, w, c = som_map.shape  # Assuming a 3D SOM map

  out_h = h // pool_size
  out_w = w // pool_size

  pooled_map = np.zeros((out_h, out_w, c))

  for i in range(out_h):
    for j in range(out_w):
      for k in range(c):
        pooled_map[i, j, k] = np.mean(som_map[i * pool_size: (i + 1) * pool_size,
                                           j * pool_size: (j + 1) * pool_size, k])

  return pooled_map

# %% [markdown]
# ## Models prediction

# %%
def som_and_rf_prediction_from_array(test_X, d_threshold, sigma, g, rf_model, comment):
  y_result = []
  rf_onlytime = 0
  for sam in test_X:
    distance_to_g = calculate_distance(sam, g, comment)
    # p_d_greater_than_x = 1 - np.exp(- (distance_to_g / sigma)**2)  # Cumulative distribution function
    is_attack = distance_to_g > d_threshold   # You can adjust the threshold as needed
    som_predicted = [1] if is_attack else [0]
    if som_predicted == [0]:
      y_result.append(som_predicted)
    else:

      rf_single_pred_start = time.time()
      rf_pred = rf_model.predict(sam.reshape(1, -1))
      rf_single_pred_end = time.time()
      rf_single_pred_time = rf_single_pred_end - rf_single_pred_start
      rf_onlytime = rf_onlytime + rf_single_pred_time
      y_result.append(rf_pred)
  print("rf_total", rf_onlytime)
  return y_result

import numpy as np
import time

def som_and_rf_prediction_from_array_optimized(test_X, d_threshold, sigma, g, rf_model, comments):
    y_result = []
    rf_onlytime = 0
    distance_to_g_all = np.array([calculate_distance(sam, g, comments) for sam in test_X])
    # p_d_greater_than_x_all = 1 - np.exp(- (distance_to_g_all / sigma)**2)

    for i, sam in enumerate(test_X):
        distance_to_g = distance_to_g_all[i]
        # p_d_greater_than_x = p_d_greater_than_x_all[i]

        is_attack = distance_to_g > d_threshold   # You can adjust the threshold as needed
        som_predicted = [1] if is_attack else [0]

        if som_predicted == [0]:
            y_result.append(som_predicted)
        else:
            rf_single_pred_start = time.time()
            rf_pred = rf_model.predict(sam.reshape(1, -1))
            rf_single_pred_end = time.time()
            rf_single_pred_time = rf_single_pred_end - rf_single_pred_start
            rf_onlytime += rf_single_pred_time
            y_result.append(rf_pred)

    print("rf_total", rf_onlytime)
    return y_result



def som_and_rf_prediction_for_single(sam, d_threshold, sigma, g, rf_model):
    # start_time = time.time()
    # som_predicted = som_prediction([sam], d_threshold, sigma, g)
    distance_to_g = calculate_distance(sam, g)
    # p_d_greater_than_x = 1 - np.exp(- (distance_to_g / sigma)**2)  # Cumulative distribution function
    is_attack = distance_to_g > d_threshold # You can adjust the threshold as needed
    som_predicted = [1] if is_attack else [0]

    if som_predicted == [0]:
      return som_predicted
    else:
      rf_single_pred_start = time.time()
      rf_pred = rf_model.predict(sam.reshape(1, -1))
      rf_single_pred_end = time.time()
      rf_single_pred_time = rf_single_pred_end - rf_single_pred_start
      # print(f"RF single pred time: {rf_single_pred_time} seconds")
      # rf_pred = [1]
      return rf_pred

      # end_time = time.time()
      # som_time = end_time - start_time
      # print(f"SOM time: {som_time:.2f} seconds")

def rf_model_prediction_for_single(test_X, rf_model):
  y_result = []
  for sam in test_X:
    rf_pred = rf_model.predict(sam.reshape(1, -1))
    y_result.append(rf_pred)
  return y_result

# %% [markdown]
# ## Models Initiation

# %%
def get_model_som(df_normalized):

  # Filter rows where label equals 0
  som_filtered_df = df_normalized[df_normalized['label'] == 0]

  som_train_X = som_filtered_df.iloc[:, :-1].values
  som_size = 30  # Example size, adjust based on your dataset
  som = MiniSom(som_size, som_size, som_train_X.shape[1], sigma=15, learning_rate=0.1, random_seed=0 )
  som.random_weights_init(som_train_X)
  som.train_batch(som_train_X, 1000, verbose = "true")
  # Calculate the reference point G
  g = np.median(som.get_weights(), axis=(0, 1))

  return g

def get_model_rf(X_train, y_train):
  # Initialize Random Forest model
  rf_model = RandomForestClassifier(random_state=42)

  # Fit the model
  rf_model.fit(X_train, y_train)

  return rf_model



def get_model_som_modified_with_attack(df_normalized):
    # Split data into normal and attack
    df_normal = df_normalized[df_normalized['label'] == 0]
    df_attack = df_normalized[df_normalized['label'] == 1]

    # Sample a portion of attack data
    attack_sample_size = int(0.2 * len(df_attack))  # Adjust sample size as needed
    df_attack_sample = df_attack.sample(n=attack_sample_size)

    # Combine normal and sampled attack data
    som_train_X = pd.concat([df_normal, df_attack_sample]).iloc[:, :-1].values

    som_size = 30  # Example size, adjust based on your dataset
    som = MiniSom(som_size, som_size, som_train_X.shape[1], sigma=15, learning_rate=0.1, random_seed=0)
    som.random_weights_init(som_train_X)
    som.train_batch(som_train_X, 1000, verbose="true")

    # Calculate the reference point G
    g = np.median(som.get_weights(), axis=(0, 1))

    return g

def get_model_som_modified_with_mean(df_normalized):

  # Filter rows where label equals 0
  som_filtered_df = df_normalized[df_normalized['label'] == 0]

  som_train_X = som_filtered_df.iloc[:, :-1].values
  som_size = 50  # Example size, adjust based on your dataset
  som = MiniSom(som_size, som_size, som_train_X.shape[1], sigma=15, learning_rate=0.1, random_seed=0 )
  som.random_weights_init(som_train_X)
  som.train_batch(som_train_X, 1000, verbose = "true")
  # Calculate the reference point G
  # g = np.median(som.get_weights(), axis=(0, 1))
  g = np.mean(som.get_weights(), axis=(0, 1))

  return g

import numpy as np
from minisom import MiniSom
from scipy.ndimage import convolve

def get_model_som_modified_with_convo(df_normalized, comments):
  # ... (similar data filtering as before)

  # Filter rows where label equals 0
  som_filtered_df = df_normalized[df_normalized['label'] == 0]

  som_train_X = som_filtered_df.iloc[:, :-1].values

  som_size = 50
  som = MiniSom(som_size, som_size, som_train_X.shape[1], sigma=15, learning_rate=0.1, random_seed=0)
  # ... (training as before)
  som.random_weights_init(som_train_X)
  som.train_batch(som_train_X, 1000, verbose="true")
  # Convert weights to a numpy array for convolution
  weights = som.get_weights()

  if 'convo' in comments:

    if 'avgpool' in comments:
      # Apply average pooling
      weights = average_pool(weights, 5)

    if 'maxpool' in comments:
      # Apply max pooling
      weights = max_pool(weights, 5)

    # Define convolution kernel (e.g., Gaussian, Laplacian)
    gaussian_kernel = np.array([[1, 1, 1],
                      [1, 1, 1],
                      [1, 1, 1]]) / 9  # Example: Gaussian blur kernel

    laplacian_kernel = np.array([[0, 1, 0],
                              [1, -4, 1],
                              [0, 1, 0]])
    # kernal selection
    if 'laplacian' in comments:
      kernel = laplacian_kernel

    if 'gaussian' in comments:
      kernel = gaussian_kernel


    # kernel = laplacian_kernel

    # Apply convolution to each feature map
    convolved_weights = np.zeros_like(weights)
    for i in range(weights.shape[2]):
        convolved_weights[:, :, i] = convolve(weights[:, :, i], kernel, mode='constant', cval=0.0)
  else:
    convolved_weights = weights

  # Calculate the reference point G (e.g., median)
  if "median" in comments:
    g = np.median(convolved_weights, axis=(0, 1))
  elif "mean" in comments:
    g = np.mean(convolved_weights, axis=(0, 1))
  else:
    print("Add mean or median")
  # g = np.median(convolved_weights, axis=(0, 1))
  # g = np.mean(convolved_weights, axis=(0, 1))

  return g

# %% [markdown]
# # Load dataset

# %%
# Load the dataset self only

urls = []
comments = []



# # #self made data
# urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/som_data.csv")
# comments.append("self made data")

# %%
# ## Load the dataset all

# urls = []
# comments = []

# # 1s split
# urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/combined%20Dataset.csv")
# comments.append("1s split caida2007")

# # #self made data
urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/som_data.csv")
comments.append("self made data")

urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/1ssplit%20combined%20dataset%20CAIDA%202007.csv")
comments.append("1s split with ")

# # new 2s splits
# #filled
urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/DATASET/caida2007/csv/2ssplit%20combined%20dataset%20CAIDA%202007%20filled.csv")
comments.append("filled 2s split with bandwidth caida 2007")

#unfilled
# urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/DATASET/caida2007/csv/2ssplit%20combined%20dataset%20CAIDA%202007%20unfilled.csv")
# comments.append("unfilled 2s split with bandwidth")

#filled
# urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/DATASET/caida2007/csv/2ssplit%20combined%20dataset%20CAIDA%202007%20filled.csv")
# comments.append("filled 2s split without bandwidth")

# unfilled
# urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/DATASET/caida2007/csv/2ssplit%20combined%20dataset%20CAIDA%202007%20unfilled.csv")
# comments.append("unfilled 2s split without bandwidth")

# ## ids 2017 benign only
# #filled
# urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/DATASET/isd%202017/ids-2017-benign-Monday-WorkingHours2s%20unlabeled_filled_entropy.csv")
# comments.append("ids 2017 benign only filled")

# urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/DATASET/isd%202017/ids-2017-benign-Monday-WorkingHours2s%20unlabeled_filled_entropy.csv")
# comments.append("ids 2017 benign only filled without bandwidth")

# ##unfilled
# urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/DATASET/isd%202017/ids-2017-benign-Monday-WorkingHours2s%20unlabeled_unfilled_entropy.csv")
# comments.append("ids 2017 benign only unfilled")

# urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/DATASET/isd%202017/ids-2017-benign-Monday-WorkingHours2s%20unlabeled_unfilled_entropy.csv")
# comments.append("ids 2017 benign only unfilled without bandwidth")

# %% [markdown]
# ## normalize_df

# %%
def normalize_df(df, mean_std_dict, comments):
    # taking x values only
    x_values = df.iloc[:, :-1].values
    # taking labels only
    labels = df.iloc[:, -1].values

    if 'tanh' in comments:
      # ## Normalizng with tanh optimization
      x_values_df = pd.DataFrame(x_values, columns=df.columns[:-1])
      normalized_xvalues = normalize_with_tanh_estimator(x_values_df, mean_std_dict)

    if 'norm' in comments:
      ## Normalizing xvalues
      normalized_xvalues = preprocessing.normalize(x_values)


    normalized_df = pd.DataFrame(normalized_xvalues, columns=df.columns[:-1])



    # Adding labels back to the normalized dataframe
    normalized_df['label'] = labels

    return normalized_df

# %% [markdown]
# ## som_with_som_and_rf_actual

# %%
def som_with_som_and_rf_actual(df, com, bandflag):
  #for  evaluating time of single evaluation

  if bandflag == 1:
    # Check if the column exists
    column_to_drop = 'bandwidth'
    if column_to_drop in df.columns:
        # Drop the column
        df.drop(columns=[column_to_drop], inplace=True)
        print(f"\n'{column_to_drop}' column dropped.")
    else:
        print(f"\nColumn '{column_to_drop}' not found in the DataFrame.")

  ## for tanh estimation
  som_d_threshold = 0.13309999999999966  # Predefined distance threshold
  som_sigma =  0.139099999999999  # Probability threshold

  ### for normalizing
  # som_d_threshold = 0.020999999999999998  # Predefined distance threshold
  # som_sigma =  0.020999999999999998  # Probability threshold


  # Define the columns to exclude from normalization
  exclude_cols = ['label']  # Add more columns here if needed
  # Calculate and store the mean and standard deviation for each dimension, excluding specified columns
  mean_std_dict = {}
  for col in df.columns:
      if col not in exclude_cols:
          mean_std_dict[col] = (df[col].mean(), df[col].std())

  # Normalize the dataset using tanh-estimator method, excluding specified columns
  # df_normalized = normalize_with_tanh_estimator(df, mean_std_dict)
  # df_normalized = df
  # using normalization of scikit learn except label column
  df_normalized = normalize_df(df, mean_std_dict)


  # Get trained som model
  g = get_model_som(df_normalized)

  #for test
  test_X = df_normalized.iloc[:, :-1].values
  test_y = df_normalized.iloc[:, -1].values

  X_train, X_test, y_train, y_test = train_test_split(test_X, test_y, test_size=0.3, random_state=42)

  rf_model = get_model_rf(X_train, y_train)




  data_size = len(test_X)
  som_start_time = time.time()
  y_pred_som = som_prediction(test_X, som_d_threshold, som_sigma, g)
  som_end_time = time.time()
  som_time = som_end_time - som_start_time
  print(f"\nSOM Avg per sample : {avg_time_per_prediction(data_size, som_time)} ms")
  print(f"SOM time: {som_time} seconds\n")

  rf_start_time = time.time()
  # y_pred_rf = rf_model.predict(test_X)
  y_pred_rf = rf_model_prediction_for_single(test_X, rf_model)
  rf_end_time = time.time()
  rf_time = rf_end_time - rf_start_time
  print(f"RF Avg per sample : {avg_time_per_prediction(data_size, rf_time)} ms")
  print(f"RF time: {rf_time} seconds\n")


  combined_start_time = time.time()
  y_pred_som_and_rf = som_and_rf_prediction_from_array_optimized(test_X, som_d_threshold, som_sigma, g, rf_model)
  combined_end_time = time.time()
  combined_time = combined_end_time - combined_start_time
  print(f"Combined Avg per sample : {avg_time_per_prediction(data_size, combined_time)} ms")
  print(f"Combined time: {combined_time} seconds\n")

  combined_start_time2 = time.time()
  y_pred_som_and_rf2 = som_and_rf_prediction_from_array(test_X, som_d_threshold, som_sigma, g, rf_model)
  combined_end_time2 = time.time()
  combined_time2 = combined_end_time2 - combined_start_time2
  print(f"Combined 2 Avg per sample : {avg_time_per_prediction(data_size, combined_time2)} ms")
  print(f"Combined 2 time: {combined_time2} seconds\n")



  #### evaluation
  print("____"*80)
  print("\n For SOM Model")
  print("--"*40)
  som_values = [evaluate_true_and_predicted_with_return(com,test_y, y_pred_som), som_time, avg_time_per_prediction(data_size, som_time)]

  print("\n For RF Model")
  print("--"*40)
  rf_values = [evaluate_true_and_predicted_with_return(com,test_y, y_pred_rf), rf_time, avg_time_per_prediction(data_size, rf_time)]

  print("\n For SOM and RF Model")
  print("--"*40)
  y_pred_som_and_rf_values = [evaluate_true_and_predicted_with_return(com,test_y, y_pred_som_and_rf), combined_time, avg_time_per_prediction(data_size, combined_time)]
  result = [som_values, rf_values, y_pred_som_and_rf_values]
  print("____"*80)
  # print(result)
  # resultant_columns = ['som_values', 'rf_values', 'y_pred_som_and_rf_values']
  # resultant_df = pd.DataFrame(result,columns=resultant_columns)
  return result

# %% [markdown]
# ## show as table

# %%
def show_as_table(data):
  # Extracting relevant data for tabulate
  table_data = []
  for item in data:
      som_row = item['som_values'][0]['evaluation1']
      rf_row = item['rf_values'][0]['evaluation1']
      combined_row = item['combined_values'][0]['evaluation1']
      comment = item['som_values'][0]['evaluation1']['com']
      d_threshold = item['som_d_threshold']
      print(f"{comment} with {d_threshold}")

      table_data.append([
          'SOM',
          som_row['accuracy'][0],
          som_row['fdr'][0],
          som_row['attack_as_normal'][0],
          som_row['normal_as_attack'][0],
          som_row['attack_as_attack'][0],
          som_row['normal_as_normal'][0],
          item['som_values'][0]['som_time'],
          item['som_values'][0]['avg_time']
      ])

      table_data.append([
          'RF',
          rf_row['accuracy'][0],
          rf_row['fdr'][0],
          rf_row['attack_as_normal'][0],
          rf_row['normal_as_attack'][0],
          rf_row['attack_as_attack'][0],
          rf_row['normal_as_normal'][0],
          item['rf_values'][0]['rf_time'],
          item['rf_values'][0]['avg_time']
      ])

      table_data.append([
          'Combined',
          combined_row['accuracy'][0],
          combined_row['fdr'][0],
          combined_row['attack_as_normal'][0],
          combined_row['normal_as_attack'][0],
          combined_row['attack_as_attack'][0],
          combined_row['normal_as_normal'][0],
          item['combined_values'][0]['combined_time'],
          item['combined_values'][0]['avg_time']
      ])

  # Headers for the table
  headers = ['Method', 'Accuracy (%)', 'FDR (%)', 'Attack as Normal', 'Normal as Attack',
            'Attack as Attack', 'Normal as Normal', 'Execution Time (s)', 'Average Time (ms)']

  # Generate the table using tabulate
  table = tabulate(table_data, headers=headers, tablefmt='grid')

  # Print the table
  print(table)

# %% [markdown]
# ## som_with_varying_sigma_and_d_threshold_ testing

# %%
def som_with_varying_sigma_and_d_threshold_for_method_testing(df, visual =1):

  df = df
  sigma_min = 0.001
  sigma_max = 1
  sigma_step = 0.0001

  ## d_threshold
  d_threshold_min = 0.001
  d_threshold_max =20
  d_threshold_step = 0.1


  # Generate arrays of varying values for sigma and d_threshold
  sigma_values = np.arange(sigma_min, sigma_max + sigma_step, sigma_step)
  d_threshold_values = np.arange(d_threshold_min, d_threshold_max + d_threshold_step, d_threshold_step)
  max = len(d_threshold_values)
  i = 1
  # Define the columns to exclude from normalization
  exclude_cols = ['label']  # Add more columns here if needed
  # Calculate and store the mean and standard deviation for each dimension, excluding specified columns
  mean_std_dict = {}
  for col in df.columns:
      if col not in exclude_cols:
          mean_std_dict[col] = (df[col].mean(), df[col].std())

  # Normalize the dataset using tanh-estimator method, excluding specified columns
  # df_normalized = normalize_with_tanh_estimator(df, mean_std_dict)
  df_normalized = normalize_df(df, mean_std_dict)
  # df_normalized = df


  # Get trained som model
  g = get_model_som_modified_with_convo(df_normalized)

  #for test
  test_X = df_normalized.iloc[:, :-1].values
  test_y = df_normalized.iloc[:, -1].values

  result = []
  sigma = 1
  # for d_threshold in d_threshold_values:
  #   # print(f"\r{i/max * 100}---  {max}")
  #   print(f"\r{((i/max) * 100):.2f} --- {max}")
  #   result.append(get_details_for_som(test_X, test_y, d_threshold, sigma, g))
  #   i=i+1
  for d_threshold in tqdm(d_threshold_values, desc="Processing d_threshold_values"):
    result.append(get_details_for_som(test_X, test_y, d_threshold, sigma, g))




  resultant_columns = ['sigma', 'd_threshold', 'accuracy', 'FDR', 'attack_as_normal', 'normal_as_attack', 'attack_as_attack', 'normal_as_normal','rocauc', 'mcc', 'eval']
  resultant_df = pd.DataFrame(result,columns=resultant_columns)
  if visual == 1:
    vision_of_varying(resultant_df)

  return resultant_df

# %% [markdown]
# ## som_with_varying_sigma_and_d_threshold_ testing2

# %%
def som_with_varying_sigma_and_d_threshold_for_method_testing_combined(df, visual =0):

  df = df
  sigma_min = 0.001
  sigma_max = 1
  sigma_step = 0.0001

  ## d_threshold
  d_threshold_min = 0.001
  d_threshold_max =5
  d_threshold_step = 0.001


  # Generate arrays of varying values for sigma and d_threshold
  sigma_values = np.arange(sigma_min, sigma_max + sigma_step, sigma_step)
  d_threshold_values = np.arange(d_threshold_min, d_threshold_max + d_threshold_step, d_threshold_step)
  max = len(d_threshold_values)
  i = 1
  # Define the columns to exclude from normalization
  exclude_cols = ['label']  # Add more columns here if needed
  # Calculate and store the mean and standard deviation for each dimension, excluding specified columns
  mean_std_dict = {}
  for col in df.columns:
      if col not in exclude_cols:
          mean_std_dict[col] = (df[col].mean(), df[col].std())

  # Normalize the dataset using tanh-estimator method, excluding specified columns
  # df_normalized = normalize_with_tanh_estimator(df, mean_std_dict)
  df_normalized = normalize_df(df, mean_std_dict)
  # df_normalized = df


  # Get trained som model
  g = get_model_som_modified_with_convo(df_normalized)

  #for test
  test_X = df_normalized.iloc[:, :-1].values
  test_y = df_normalized.iloc[:, -1].values

  result = []
  sigma = 1

  for d_threshold in tqdm(d_threshold_values, desc="Processing d_threshold_values"):
    result.append(get_details_for_som(test_X, test_y, d_threshold, sigma, g))




  resultant_columns = ['sigma', 'd_threshold', 'accuracy', 'FDR', 'attack_as_normal', 'normal_as_attack', 'attack_as_attack', 'normal_as_normal','rocauc', 'mcc', 'eval']
  resultant_df = pd.DataFrame(result,columns=resultant_columns)
  if visual == 1:
    vision_of_varying(resultant_df)

  d_threshold_value = get_d_threshold_value_for_max_eval(resultant_df)
  print(f"d_threshold_value from function : {d_threshold_value}")

  return d_threshold_value

# %% [markdown]
# ## som_with_som_and_rf_actual_modified_som testing

# %%
def som_with_som_and_rf_actual_modified_som(df, com, bandflag):
  #for  evaluating time of single evaluation

  if bandflag == 1:
    # Check if the column exists
    column_to_drop = 'bandwidth'
    if column_to_drop in df.columns:
        # Drop the column
        df.drop(columns=[column_to_drop], inplace=True)
        print(f"\n'{column_to_drop}' column dropped.")
    else:
        print(f"\nColumn '{column_to_drop}' not found in the DataFrame.")

  # ## for tanh estimation
  # som_d_threshold = 0.13309999999999966  # Predefined distance threshold
  som_sigma =  0.139099999999999  # Probability threshold

  ### for normalizing
  # som_d_threshold = 0.020999999999999998  # Predefined distance threshold
  # som_sigma =  0.020999999999999998  # Probability threshold

  ### for convolution
  som_d_threshold = 1.081 # predefined


  # Define the columns to exclude from normalization
  exclude_cols = ['label']  # Add more columns here if needed
  # Calculate and store the mean and standard deviation for each dimension, excluding specified columns
  mean_std_dict = {}
  for col in df.columns:
      if col not in exclude_cols:
          mean_std_dict[col] = (df[col].mean(), df[col].std())

  # Normalize the dataset using tanh-estimator method, excluding specified columns
  # df_normalized = normalize_with_tanh_estimator(df, mean_std_dict)
  # df_normalized = df
  # using normalization of scikit learn except label column
  df_normalized = normalize_df(df, mean_std_dict)


  # Get trained som model
  g = get_model_som_modified_with_convo(df_normalized)

  #for test
  test_X = df_normalized.iloc[:, :-1].values
  test_y = df_normalized.iloc[:, -1].values

  X_train, X_test, y_train, y_test = train_test_split(test_X, test_y, test_size=0.3, random_state=42)

  rf_model = get_model_rf(X_train, y_train)




  data_size = len(test_X)
  som_start_time = time.time()
  y_pred_som = som_prediction(test_X, som_d_threshold, som_sigma, g)
  som_end_time = time.time()
  som_time = som_end_time - som_start_time
  print(f"\nSOM Avg per sample : {avg_time_per_prediction(data_size, som_time)} ms")
  print(f"SOM time: {som_time} seconds\n")

  rf_start_time = time.time()
  # y_pred_rf = rf_model.predict(test_X)
  y_pred_rf = rf_model_prediction_for_single(test_X, rf_model)
  rf_end_time = time.time()
  rf_time = rf_end_time - rf_start_time
  print(f"RF Avg per sample : {avg_time_per_prediction(data_size, rf_time)} ms")
  print(f"RF time: {rf_time} seconds\n")


  combined_start_time = time.time()
  y_pred_som_and_rf = som_and_rf_prediction_from_array_optimized(test_X, som_d_threshold, som_sigma, g, rf_model)
  combined_end_time = time.time()
  combined_time = combined_end_time - combined_start_time
  print(f"Combined Avg per sample : {avg_time_per_prediction(data_size, combined_time)} ms")
  print(f"Combined time: {combined_time} seconds\n")

  combined_start_time2 = time.time()
  y_pred_som_and_rf2 = som_and_rf_prediction_from_array(test_X, som_d_threshold, som_sigma, g, rf_model)
  combined_end_time2 = time.time()
  combined_time2 = combined_end_time2 - combined_start_time2
  print(f"Combined 2 Avg per sample : {avg_time_per_prediction(data_size, combined_time2)} ms")
  print(f"Combined 2 time: {combined_time2} seconds\n")



  #### evaluation
  print("____"*80)
  print("\n For SOM Model")
  print("--"*40)
  som_values = [evaluate_true_and_predicted_with_return(com,test_y, y_pred_som), som_time, avg_time_per_prediction(data_size, som_time)]

  print("\n For RF Model")
  print("--"*40)
  rf_values = [evaluate_true_and_predicted_with_return(com,test_y, y_pred_rf), rf_time, avg_time_per_prediction(data_size, rf_time)]

  print("\n For SOM and RF Model")
  print("--"*40)
  y_pred_som_and_rf_values = [evaluate_true_and_predicted_with_return(com,test_y, y_pred_som_and_rf), combined_time, avg_time_per_prediction(data_size, combined_time)]
  result = [som_values, rf_values, y_pred_som_and_rf_values]
  print("____"*80)
  # print(result)
  # resultant_columns = ['som_values', 'rf_values', 'y_pred_som_and_rf_values']
  # resultant_df = pd.DataFrame(result,columns=resultant_columns)
  return result

# %% [markdown]
# ## som_with_som_and_rf_actual_modified_som testing2

# %%
def som_with_som_and_rf_actual_modified_som_combined(df, com, bandflag, comments):
  #for  evaluating time of single evaluation

  if bandflag == 1:
    # Check if the column exists
    column_to_drop = 'bandwidth'
    if column_to_drop in df.columns:
        # Drop the column
        df.drop(columns=[column_to_drop], inplace=True)
        print(f"\n'{column_to_drop}' column dropped.")
    else:
        print(f"\nColumn '{column_to_drop}' not found in the DataFrame.")

  # ## for tanh estimation
  # som_d_threshold = 0.13309999999999966  # Predefined distance threshold
  som_sigma =  0.139099999999999  # Probability threshold

  ### for normalizing
  # som_d_threshold = 0.020999999999999998  # Predefined distance threshold
  # som_sigma =  0.020999999999999998  # Probability threshold

  ### for convolution
  # som_d_threshold = 1.081 # predefined
  # som_d_threshold = som_with_varying_sigma_and_d_threshold_for_method_testing_combined(df)




  # Define the columns to exclude from normalization
  exclude_cols = ['label']  # Add more columns here if needed
  # Calculate and store the mean and standard deviation for each dimension, excluding specified columns
  mean_std_dict = {}
  for col in df.columns:
      if col not in exclude_cols:
          mean_std_dict[col] = (df[col].mean(), df[col].std())

  # Normalize the dataset using tanh-estimator method, excluding specified columns
  # df_normalized = normalize_with_tanh_estimator(df, mean_std_dict)
  # df_normalized = df
  # using normalization of scikit learn except label column
  df_normalized = normalize_df(df, mean_std_dict,comments)


  # Get trained som model
  g = get_model_som_modified_with_convo(df_normalized, comments)

  #for test
  test_X = df_normalized.iloc[:, :-1].values
  test_y = df_normalized.iloc[:, -1].values

  # d_threshold_min = 0.001
  # d_threshold_max = 20
  # som_d_threshold = genetic_algorithm(df, num_generations=100, population_size=50, crossover_rate=0.8, mutation_rate=0.2, test_X,test_y)
  som_d_threshold = genetic_algorithm(df, 50, 30, 0.8, 0.2, test_X,test_y, g,comments)

  print(f"som_d_threshold : {som_d_threshold}")

  X_train, X_test, y_train, y_test = train_test_split(test_X, test_y, test_size=0.3, random_state=42)

  rf_model = get_model_rf(X_train, y_train)




  data_size = len(test_X)
  som_start_time = time.time()
  y_pred_som = som_prediction(test_X, som_d_threshold, som_sigma, g, comments)
  som_end_time = time.time()
  som_time = som_end_time - som_start_time
  print(f"\nSOM Avg per sample : {avg_time_per_prediction(data_size, som_time)} ms")
  print(f"SOM time: {som_time} seconds\n")

  rf_start_time = time.time()
  # y_pred_rf = rf_model.predict(test_X)
  y_pred_rf = rf_model_prediction_for_single(test_X, rf_model)
  rf_end_time = time.time()
  rf_time = rf_end_time - rf_start_time
  print(f"RF Avg per sample : {avg_time_per_prediction(data_size, rf_time)} ms")
  print(f"RF time: {rf_time} seconds\n")


  combined_start_time = time.time()
  y_pred_som_and_rf = som_and_rf_prediction_from_array_optimized(test_X, som_d_threshold, som_sigma, g, rf_model, comments)
  combined_end_time = time.time()
  combined_time = combined_end_time - combined_start_time
  print(f"Combined Avg per sample : {avg_time_per_prediction(data_size, combined_time)} ms")
  print(f"Combined time: {combined_time} seconds\n")

  # combined_start_time2 = time.time()
  # y_pred_som_and_rf2 = som_and_rf_prediction_from_array(test_X, som_d_threshold, som_sigma, g, rf_model)
  # combined_end_time2 = time.time()
  # combined_time2 = combined_end_time2 - combined_start_time2
  # print(f"Combined 2 Avg per sample : {avg_time_per_prediction(data_size, combined_time2)} ms")
  # print(f"Combined 2 time: {combined_time2} seconds\n")



  #### evaluation
  print("____"*80)
  print("\n For SOM Model")
  print("--"*40)
  som_values = [evaluate_true_and_predicted_with_return(com,test_y, y_pred_som), som_time, avg_time_per_prediction(data_size, som_time)]
  som_values_dict = {'evaluation1': som_values[0], 'som_time': som_time, 'avg_time' : som_values[2] }

  print("\n For RF Model")
  print("--"*40)
  rf_values = [evaluate_true_and_predicted_with_return(com,test_y, y_pred_rf), rf_time, avg_time_per_prediction(data_size, rf_time)]
  rf_values_dict = {'evaluation1': rf_values[0], 'rf_time': rf_time, 'avg_time' : rf_values[2] }
  print("\n For SOM and RF Model")
  print("--"*40)
  y_pred_som_and_rf_values = [evaluate_true_and_predicted_with_return(com,test_y, y_pred_som_and_rf), combined_time, avg_time_per_prediction(data_size, combined_time)]
  combined_values_dict = {'evaluation1': y_pred_som_and_rf_values[0], 'combined_time': combined_time, 'avg_time' : y_pred_som_and_rf_values[2] }
  result = [som_values_dict, rf_values_dict, combined_values_dict, som_d_threshold]
  columns = ["som_values","rf_values", "combined_values", "som_d_threshold"]
  data_dict = {col: [val] for col, val in zip(columns, result)}
  print("____"*80)
  # print(result)
  # resultant_columns = ['som_values', 'rf_values', 'y_pred_som_and_rf_values']
  # resultant_df = pd.DataFrame(result,columns=resultant_columns)
  return data_dict

# %% [markdown]
# ## max eval d_threshold

# %%
def get_d_threshold_value_for_max_eval(value_pd):
    # printing all the max eval rows
    max_eval_rows = value_pd[value_pd['eval'] == value_pd['eval'].max()]

    # Check if there's more than one row with maximum 'eval'
    if len(max_eval_rows) > 1:
        # Find the row with the lowest 'attack_as_normal' value
        min_attack_row = max_eval_rows.loc[max_eval_rows['attack_as_normal'].idxmin()]
        print(min_attack_row['d_threshold'])
        return min_attack_row['d_threshold']
    else:
        # If only one row has maximum 'eval', print that d_threshold of that row
        print(max_eval_rows['d_threshold'].iloc[0])
        return max_eval_rows['d_threshold'].iloc[0]

# %% [markdown]
# ## vision

# %%
def vision_of_varying(df_results):
  import numpy as np
  import pandas as pd
  import matplotlib.pyplot as plt
  from mpl_toolkits.mplot3d import Axes3D
  import matplotlib.pyplot as plt
  import seaborn as sns

  if not True:
    # Assuming df_results contains the data from the previous code snippet

    # Convert dataframe columns to numpy arrays for plotting
    sigma_values = df_results['sigma'].values
    d_threshold_values = df_results['d_threshold'].values
    accuracy_values = df_results['accuracy'].values

    # Create a 3D plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Plot the surface
    ax.plot_trisurf(sigma_values, d_threshold_values, accuracy_values, cmap='viridis')

    # Set labels and title
    ax.set_xlabel('Sigma')
    ax.set_ylabel('d_threshold')
    ax.set_zlabel('Accuracy')
    ax.set_title('Accuracy vs. Sigma and d_threshold')

    # Show the plot
    plt.show()

  else:
      # Convert dataframe columns to numpy arrays for plotting
      d_threshold_values = df_results['d_threshold'].values
      accuracy_values = df_results['accuracy'].values
      fdr = df_results['FDR'].values

      # # Create a 2D plot (For showing only)
      # plt.figure()

      # # Plot the data
      # plt.plot(d_threshold_values, accuracy_values, marker='o', linestyle='-')

      # # Set labels and title
      # plt.xlabel('d_threshold')
      # plt.ylabel('Accuracy')
      # plt.title('Accuracy vs. d_threshold')

      # # Show the plot
      # plt.show()



  # Plotting changes in accuracy with respect to d_threshold
  plt.figure(figsize=(10, 6))
  sns.lineplot(data=df_results, x='d_threshold', y='accuracy', hue='sigma', marker='o')
  plt.title('Accuracy vs d_threshold')
  plt.xlabel('d_threshold')
  plt.ylabel('Accuracy')
  plt.legend(title='sigma')
  plt.grid(True)
  plt.show()

  # Plotting changes in fdr with respect to d_threshold
  plt.figure(figsize=(10, 6))
  sns.lineplot(data=df_results, x='d_threshold', y='FDR', hue='sigma', marker='o')
  plt.title('FDR vs d_threshold')
  plt.xlabel('d_threshold')
  plt.ylabel('FDR')
  plt.legend(title='sigma')
  plt.grid(True)
  plt.show()

  # Plotting changes in rocauc with respect to d_threshold

  plt.figure(figsize=(10, 6))
  sns.lineplot(data=df_results, x='d_threshold', y='rocauc', hue='sigma', marker='o')
  plt.title('rocauc vs d_threshold')
  plt.xlabel('d_threshold')
  plt.ylabel('rocauc')
  plt.legend(title='sigma')
  plt.grid(True)
  plt.show()

  # Plotting changes in mcc with respect to d_threshold color green
  plt.figure(figsize=(10, 6))
  sns.lineplot(data=df_results, x='d_threshold', y='mcc', hue='sigma', marker='o')
  plt.title('mcc vs d_threshold')
  plt.xlabel('d_threshold')
  plt.ylabel('mcc')
  plt.legend(title='sigma')
  plt.grid(True)
  plt.show()

  # Plotting changes in eval with respect to d_threshold graph color green
  plt.figure(figsize=(10, 6))
  sns.lineplot(data=df_results, x='d_threshold', y='eval', hue='sigma', marker='o')
  plt.title('eval vs d_threshold')
  plt.xlabel('d_threshold')
  plt.ylabel('eval')
  plt.legend(title='sigma')
  plt.grid(True)
  plt.show()

# %% [markdown]
# ## config

# %%
def make_configurations () :

  configurations = []

  # # Define the possible values for each parameter
  # activation_functions = ['norm', 'tanh']
  # convolution_types = [None, 'convo']
  # pooling_types = ['avgpool', 'maxpool']
  # filter_types = ['laplacian', 'gaussian']
  # aggregation_methods = ['mean', 'median']
  # distance_methods = ['euclidean', 'manhattan', 'chebyshev', 'cosine']

  # # Generate all combinations using itertools.product
  # for activation, convo, pooling, filter_type, aggregation,distance_method in product(activation_functions, convolution_types, pooling_types, filter_types, aggregation_methods, distance_methods):
  #     config_list = [activation]
  #     if convo is not None:
  #         config_list.extend([convo, pooling, filter_type])
  #     config_list.append(aggregation)
  #     config_list.append(distance_method)
  #     config_string = ' '.join(config_list)
  #     configurations.append(config_string)
  # configurations = ['tanh convo maxpool gaussian mean euclidean', 'tanh convo maxpool gaussian mean manhattan', 'tanh convo maxpool gaussian mean chebyshev', 'tanh convo maxpool gaussian mean cosine']
  configurations = ['tanh convo gaussian mean cosine','tanh convo maxpool gaussian mean cosine']

  return configurations
# for config in configurations:
#   print(config)

# %%
# jjk = make_configurations()
# jjk

# %%
# result_som_with_varying_sigma_and_d_threshold = som_with_varying_sigma_and_d_threshold(df)

# %%
def config_call(df,comment, bandflag):
  value = {}
  configurations = make_configurations()
  # configurations = ['norm mean', 'norm median']
  # for comments in tqdm(configurations):
  for comments in configurations:
    # print(f"on {comments}")
    current = (som_with_som_and_rf_actual_modified_som_combined(df,comment, bandflag, comments))
    value[f'{comments}'] = current
    # print(f"on {comments}")
    # show_as_table(current)

  return value

# %% [markdown]
# ## main

# %%
# #self made data
# urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/som_data.csv")
# comments.append("self made data")





results = []
iteration = 0
for url in urls:
  comment = comments[iteration]
  if 'without bandwidth' in comment:
    bandflag = 1
  else:
    bandflag = 0
  print(f"Iteration : {iteration}")

  df = pd.read_csv(url)
  if iteration >= len(results):
        results.append([])
  # y_pred_som_and_rf = with_som_and_rf(df,comment, bandflag) # without rf modify
  # value = som_with_som_and_rf_actual(df,comment, bandflag) # with rfmodify and working
  # value = som_with_varying_sigma_and_d_threshold(df) # finding value for sigma and d_threshold
  # value = som_with_varying_sigma_and_d_threshold_for_method_testing(df) # testing for sigma and d_value on modified
  # value = som_with_som_and_rf_actual_modified_som(df,comment, bandflag) # testing for all datasets with modified som
  value = config_call(df,comment, bandflag) # testing for all datasets with modified som and rf

  results[iteration].append(value)
  iteration = iteration + 1
# Out:
# Iteration : 0
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 0.006685477022843407
# 100%|██████████| 50/50 [00:48<00:00,  1.02it/s]
# som_d_threshold : 0.007010754604790339
#
# SOM Avg per sample : 0.020527571774600597 ms
# SOM time: 0.01826953887939453 seconds
#
# RF Avg per sample : 6.029494692770283 ms
# RF time: 5.366250276565552 seconds
#
# rf_total 2.6651082038879395
# Combined Avg per sample : 3.015519795792826 ms
# Combined time: 2.6838126182556152 seconds
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#
#  For SOM Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94       470
#            1       0.92      0.94      0.93       420
#
#     accuracy                           0.93       890
#    macro avg       0.93      0.93      0.93       890
# weighted avg       0.93      0.93      0.93       890
#
#
# Accuracy : 93.37078651685393 %
# False Detection Rate (FDR): 7.73%
# ['self made data', 93.37078651685393, 7.728337236533955, 26, 33, 394, 437]
#
#  self made data
#
#  For RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       470
#            1       1.00      1.00      1.00       420
#
#     accuracy                           1.00       890
#    macro avg       1.00      1.00      1.00       890
# weighted avg       1.00      1.00      1.00       890
#
#
# Accuracy : 99.8876404494382 %
# False Detection Rate (FDR): 0.00%
# ['self made data', 99.8876404494382, 0.0, 1, 0, 419, 470]
#
#  self made data
#
#  For SOM and RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       470
#            1       1.00      0.94      0.97       420
#
#     accuracy                           0.97       890
#    macro avg       0.97      0.97      0.97       890
# weighted avg       0.97      0.97      0.97       890
#
#
# Accuracy : 97.07865168539325 %
# False Detection Rate (FDR): 0.00%
# ['self made data', 97.07865168539325, 0.0, 26, 0, 394, 470]
#
#  self made data
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 0.006685477022843407
# 100%|██████████| 50/50 [00:43<00:00,  1.15it/s]
# som_d_threshold : 0.005739727593789745
#
# SOM Avg per sample : 0.020212805672977747 ms
# SOM time: 0.017989397048950195 seconds
#
# RF Avg per sample : 5.936115511347739 ms
# RF time: 5.283142805099487 seconds
#
# rf_total 2.6594698429107666
# Combined Avg per sample : 3.005707665775599 ms
# Combined time: 2.675079822540283 seconds
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#
#  For SOM Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94       470
#            1       0.92      0.95      0.93       420
#
#     accuracy                           0.93       890
#    macro avg       0.93      0.94      0.93       890
# weighted avg       0.94      0.93      0.93       890
#
#
# Accuracy : 93.48314606741573 %
# False Detection Rate (FDR): 8.49%
# ['self made data', 93.48314606741573, 8.486238532110091, 21, 37, 399, 433]
#
#  self made data
#
#  For RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       470
#            1       1.00      1.00      1.00       420
#
#     accuracy                           1.00       890
#    macro avg       1.00      1.00      1.00       890
# weighted avg       1.00      1.00      1.00       890
#
#
# Accuracy : 99.8876404494382 %
# False Detection Rate (FDR): 0.00%
# ['self made data', 99.8876404494382, 0.0, 1, 0, 419, 470]
#
#  self made data
#
#  For SOM and RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       470
#            1       1.00      0.95      0.97       420
#
#     accuracy                           0.98       890
#    macro avg       0.98      0.97      0.98       890
# weighted avg       0.98      0.98      0.98       890
#
#
# Accuracy : 97.64044943820225 %
# False Detection Rate (FDR): 0.00%
# ['self made data', 97.64044943820225, 0.0, 21, 0, 399, 470]
#
#  self made data
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# Iteration : 1
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 0.004092786086949233
# 100%|██████████| 50/50 [02:17<00:00,  2.74s/it]
# som_d_threshold : 0.005182562815730184
#
# SOM Avg per sample : 0.011044501734591657 ms
# SOM time: 0.04022407531738281 seconds
#
# RF Avg per sample : 5.741132019248263 ms
# RF time: 20.909202814102173 seconds
#
# rf_total 12.219406843185425
# Combined Avg per sample : 3.3812638104191066 ms
# Combined time: 12.314562797546387 seconds
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#
#  For SOM Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      1495
#            1       0.97      0.96      0.97      2147
#
#     accuracy                           0.96      3642
#    macro avg       0.96      0.96      0.96      3642
# weighted avg       0.96      0.96      0.96      3642
#
#
# Accuracy : 96.18341570565623 %
# False Detection Rate (FDR): 2.60%
# ['1s split with ', 96.18341570565623, 2.596789423984891, 84, 55, 2063, 1440]
#
#  1s split with
#
#  For RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1495
#            1       1.00      1.00      1.00      2147
#
#     accuracy                           1.00      3642
#    macro avg       1.00      1.00      1.00      3642
# weighted avg       1.00      1.00      1.00      3642
#
#
# Accuracy : 100.0 %
# False Detection Rate (FDR): 0.00%
# ['1s split with ', 100.0, 0.0, 0, 0, 2147, 1495]
#
#  1s split with
#
#  For SOM and RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1495
#            1       1.00      0.96      0.98      2147
#
#     accuracy                           0.98      3642
#    macro avg       0.97      0.98      0.98      3642
# weighted avg       0.98      0.98      0.98      3642
#
#
# Accuracy : 97.69357495881383 %
# False Detection Rate (FDR): 0.00%
# ['1s split with ', 97.69357495881383, 0.0, 84, 0, 2063, 1495]
#
#  1s split with
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 0.004092786086949233
# 100%|██████████| 50/50 [02:18<00:00,  2.77s/it]
# som_d_threshold : 0.006289480875135589
#
# SOM Avg per sample : 0.010999200895289548 ms
# SOM time: 0.04005908966064453 seconds
#
# RF Avg per sample : 6.097486620090742 ms
# RF time: 22.207046270370483 seconds
#
# rf_total 12.032713413238525
# Combined Avg per sample : 3.321036671885156 ms
# Combined time: 12.095215559005737 seconds
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#
#  For SOM Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96      1495
#            1       0.99      0.95      0.97      2147
#
#     accuracy                           0.96      3642
#    macro avg       0.96      0.97      0.96      3642
# weighted avg       0.96      0.96      0.96      3642
#
#
# Accuracy : 96.23833058758923 %
# False Detection Rate (FDR): 1.36%
# ['1s split with ', 96.23833058758923, 1.3552758954501476, 109, 28, 2038, 1467]
#
#  1s split with
#
#  For RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1495
#            1       1.00      1.00      1.00      2147
#
#     accuracy                           1.00      3642
#    macro avg       1.00      1.00      1.00      3642
# weighted avg       1.00      1.00      1.00      3642
#
#
# Accuracy : 100.0 %
# False Detection Rate (FDR): 0.00%
# ['1s split with ', 100.0, 0.0, 0, 0, 2147, 1495]
#
#  1s split with
#
#  For SOM and RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      1495
#            1       1.00      0.95      0.97      2147
#
#     accuracy                           0.97      3642
#    macro avg       0.97      0.97      0.97      3642
# weighted avg       0.97      0.97      0.97      3642
#
#
# Accuracy : 97.0071389346513 %
# False Detection Rate (FDR): 0.00%
# ['1s split with ', 97.0071389346513, 0.0, 109, 0, 2038, 1495]
#
#  1s split with
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# Iteration : 2
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 0.004415748322210984
# 100%|██████████| 50/50 [01:14<00:00,  1.49s/it]
# som_d_threshold : 0.004054681100684127
#
# SOM Avg per sample : 0.020930490556378856 ms
# SOM time: 0.03826093673706055 seconds
#
# RF Avg per sample : 5.649912018222935 ms
# RF time: 10.328039169311523 seconds
#
# rf_total 7.299378156661987
# Combined Avg per sample : 4.011438894584873 ms
# Combined time: 7.3329102993011475 seconds
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#
#  For SOM Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87       600
#            1       0.95      0.92      0.93      1228
#
#     accuracy                           0.91      1828
#    macro avg       0.90      0.91      0.90      1828
# weighted avg       0.92      0.91      0.91      1828
#
#
# Accuracy : 91.2472647702407 %
# False Detection Rate (FDR): 4.82%
# ['filled 2s split with bandwidth caida 2007', 91.2472647702407, 4.822335025380708, 103, 57, 1125, 543]
#
#  filled 2s split with bandwidth caida 2007
#
#  For RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       600
#            1       1.00      0.99      1.00      1228
#
#     accuracy                           1.00      1828
#    macro avg       0.99      1.00      0.99      1828
# weighted avg       1.00      1.00      1.00      1828
#
#
# Accuracy : 99.50765864332604 %
# False Detection Rate (FDR): 0.00%
# ['filled 2s split with bandwidth caida 2007', 99.50765864332604, 0.0, 9, 0, 1219, 600]
#
#  filled 2s split with bandwidth caida 2007
#
#  For SOM and RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92       600
#            1       1.00      0.91      0.95      1228
#
#     accuracy                           0.94      1828
#    macro avg       0.92      0.96      0.94      1828
# weighted avg       0.95      0.94      0.94      1828
#
#
# Accuracy : 94.14660831509846 %
# False Detection Rate (FDR): 0.00%
# ['filled 2s split with bandwidth caida 2007', 94.14660831509846, 0.0, 107, 0, 1121, 600]
#
#  filled 2s split with bandwidth caida 2007
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 0.004415748322210984
# 100%|██████████| 50/50 [01:15<00:00,  1.51s/it]
# som_d_threshold : 0.004927668881269758
#
# SOM Avg per sample : 0.020636771387813908 ms
# SOM time: 0.03772401809692383 seconds
#
# RF Avg per sample : 5.636123781392037 ms
# RF time: 10.302834272384644 seconds
#
# rf_total 7.10882830619812
# Combined Avg per sample : 3.9084748053185527 ms
# Combined time: 7.1446919441223145 seconds
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#
#  For SOM Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88       600
#            1       0.97      0.90      0.93      1228
#
#     accuracy                           0.91      1828
#    macro avg       0.90      0.92      0.91      1828
# weighted avg       0.92      0.91      0.92      1828
#
#
# Accuracy : 91.41137855579868 %
# False Detection Rate (FDR): 3.07%
# ['filled 2s split with bandwidth caida 2007', 91.41137855579868, 3.0674846625766916, 122, 35, 1106, 565]
#
#  filled 2s split with bandwidth caida 2007
#
#  For RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       600
#            1       1.00      0.99      1.00      1228
#
#     accuracy                           1.00      1828
#    macro avg       0.99      1.00      0.99      1828
# weighted avg       1.00      1.00      1.00      1828
#
#
# Accuracy : 99.50765864332604 %
# False Detection Rate (FDR): 0.00%
# ['filled 2s split with bandwidth caida 2007', 99.50765864332604, 0.0, 9, 0, 1219, 600]
#
#  filled 2s split with bandwidth caida 2007
#
#  For SOM and RF Model
# --------------------------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91       600
#            1       1.00      0.90      0.95      1228
#
#     accuracy                           0.93      1828
#    macro avg       0.91      0.95      0.93      1828
# weighted avg       0.94      0.93      0.93      1828
#
#
# Accuracy : 93.21663019693655 %
# False Detection Rate (FDR): 0.00%
# ['filled 2s split with bandwidth caida 2007', 93.21663019693655, 0.0, 124, 0, 1104, 600]
#
#  filled 2s split with bandwidth caida 2007
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
results
# Out:
# [[{'tanh convo gaussian mean cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [93.37078651685393],
#        'fdr': [7.728337236533955],
#        'attack_as_normal': [26],
#        'normal_as_attack': [33],
#        'attack_as_attack': [394],
#        'normal_as_normal': [437]},
#       'som_time': 0.01826953887939453,
#       'avg_time': 0.020527571774600597}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [99.8876404494382],
#        'fdr': [0.0],
#        'attack_as_normal': [1],
#        'normal_as_attack': [0],
#        'attack_as_attack': [419],
#        'normal_as_normal': [470]},
#       'rf_time': 5.366250276565552,
#       'avg_time': 6.029494692770283}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [97.07865168539325],
#        'fdr': [0.0],
#        'attack_as_normal': [26],
#        'normal_as_attack': [0],
#        'attack_as_attack': [394],
#        'normal_as_normal': [470]},
#       'combined_time': 2.6838126182556152,
#       'avg_time': 3.015519795792826}],
#     'som_d_threshold': [0.007010754604790339]},
#    'tanh convo maxpool gaussian mean cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [93.48314606741573],
#        'fdr': [8.486238532110091],
#        'attack_as_normal': [21],
#        'normal_as_attack': [37],
#        'attack_as_attack': [399],
#        'normal_as_normal': [433]},
#       'som_time': 0.017989397048950195,
#       'avg_time': 0.020212805672977747}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [99.8876404494382],
#        'fdr': [0.0],
#        'attack_as_normal': [1],
#        'normal_as_attack': [0],
#        'attack_as_attack': [419],
#        'normal_as_normal': [470]},
#       'rf_time': 5.283142805099487,
#       'avg_time': 5.936115511347739}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [97.64044943820225],
#        'fdr': [0.0],
#        'attack_as_normal': [21],
#        'normal_as_attack': [0],
#        'attack_as_attack': [399],
#        'normal_as_normal': [470]},
#       'combined_time': 2.675079822540283,
#       'avg_time': 3.005707665775599}],
#     'som_d_threshold': [0.005739727593789745]}}],
#  [{'tanh convo gaussian mean cosine': {'som_values': [{'evaluation1': {'com': ['1s split with '],
#        'accuracy': [96.18341570565623],
#        'fdr': [2.596789423984891],
#        'attack_as_normal': [84],
#        'normal_as_attack': [55],
#        'attack_as_attack': [2063],
#        'normal_as_normal': [1440]},
#       'som_time': 0.04022407531738281,
#       'avg_time': 0.011044501734591657}],
#     'rf_values': [{'evaluation1': {'com': ['1s split with '],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [2147],
#        'normal_as_normal': [1495]},
#       'rf_time': 20.909202814102173,
#       'avg_time': 5.741132019248263}],
#     'combined_values': [{'evaluation1': {'com': ['1s split with '],
#        'accuracy': [97.69357495881383],
#        'fdr': [0.0],
#        'attack_as_normal': [84],
#        'normal_as_attack': [0],
#        'attack_as_attack': [2063],
#        'normal_as_normal': [1495]},
#       'combined_time': 12.314562797546387,
#       'avg_time': 3.3812638104191066}],
#     'som_d_threshold': [0.005182562815730184]},
#    'tanh convo maxpool gaussian mean cosine': {'som_values': [{'evaluation1': {'com': ['1s split with '],
#        'accuracy': [96.23833058758923],
#        'fdr': [1.3552758954501476],
#        'attack_as_normal': [109],
#        'normal_as_attack': [28],
#        'attack_as_attack': [2038],
#        'normal_as_normal': [1467]},
#       'som_time': 0.04005908966064453,
#       'avg_time': 0.010999200895289548}],
#     'rf_values': [{'evaluation1': {'com': ['1s split with '],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [2147],
#        'normal_as_normal': [1495]},
#       'rf_time': 22.207046270370483,
#       'avg_time': 6.097486620090742}],
#     'combined_values': [{'evaluation1': {'com': ['1s split with '],
#        'accuracy': [97.0071389346513],
#        'fdr': [0.0],
#        'attack_as_normal': [109],
#        'normal_as_attack': [0],
#        'attack_as_attack': [2038],
#        'normal_as_normal': [1495]},
#       'combined_time': 12.095215559005737,
#       'avg_time': 3.321036671885156}],
#     'som_d_threshold': [0.006289480875135589]}}],
#  [{'tanh convo gaussian mean cosine': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [91.2472647702407],
#        'fdr': [4.822335025380708],
#        'attack_as_normal': [103],
#        'normal_as_attack': [57],
#        'attack_as_attack': [1125],
#        'normal_as_normal': [543]},
#       'som_time': 0.03826093673706055,
#       'avg_time': 0.020930490556378856}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 10.328039169311523,
#       'avg_time': 5.649912018222935}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [94.14660831509846],
#        'fdr': [0.0],
#        'attack_as_normal': [107],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1121],
#        'normal_as_normal': [600]},
#       'combined_time': 7.3329102993011475,
#       'avg_time': 4.011438894584873}],
#     'som_d_threshold': [0.004054681100684127]},
#    'tanh convo maxpool gaussian mean cosine': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [91.41137855579868],
#        'fdr': [3.0674846625766916],
#        'attack_as_normal': [122],
#        'normal_as_attack': [35],
#        'attack_as_attack': [1106],
#        'normal_as_normal': [565]},
#       'som_time': 0.03772401809692383,
#       'avg_time': 0.020636771387813908}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 10.302834272384644,
#       'avg_time': 5.636123781392037}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [93.21663019693655],
#        'fdr': [0.0],
#        'attack_as_normal': [124],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1104],
#        'normal_as_normal': [600]},
#       'combined_time': 7.1446919441223145,
#       'avg_time': 3.9084748053185527}],
#     'som_d_threshold': [0.004927668881269758]}}]]

# %%
# #save results to self_data_only.pkl
# with open('all_data_trial.pkl', 'wb') as f:
#     pickle.dump(results, f)

# read file all_data_trial.pkl as results
with open('all_data_trial.pkl', 'rb') as f:
    results = pickle.load(f)

# %%
results
# Out:
# [[{'norm mean euclidean': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [64.49438202247191],
#        'fdr': [11.764705882352944],
#        'attack_as_normal': [300],
#        'normal_as_attack': [16],
#        'attack_as_attack': [120],
#        'normal_as_normal': [454]},
#       'som_time': 0.012663602828979492,
#       'avg_time': 0.014228767223572462}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.7169671058654785,
#       'avg_time': 5.29996304029829}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [66.29213483146067],
#        'fdr': [0.0],
#        'attack_as_normal': [300],
#        'normal_as_attack': [0],
#        'attack_as_attack': [120],
#        'normal_as_normal': [470]},
#       'combined_time': 0.7094855308532715,
#       'avg_time': 0.7971747537677207}],
#     'som_d_threshold': [0.08043873807603849]},
#    'norm mean manhattan': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [64.38202247191012],
#        'fdr': [11.27819548872181],
#        'attack_as_normal': [302],
#        'normal_as_attack': [15],
#        'attack_as_attack': [118],
#        'normal_as_normal': [455]},
#       'som_time': 0.006688833236694336,
#       'avg_time': 0.0075155429625779055}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.6304566860198975,
#       'avg_time': 5.202760321370671}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [66.06741573033707],
#        'fdr': [0.0],
#        'attack_as_normal': [302],
#        'normal_as_attack': [0],
#        'attack_as_attack': [118],
#        'normal_as_normal': [470]},
#       'combined_time': 0.6885075569152832,
#       'avg_time': 0.7736039965340261}],
#     'som_d_threshold': [0.1631711399517969]},
#    'norm mean chebyshev': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [64.9438202247191],
#        'fdr': [11.971830985915489],
#        'attack_as_normal': [295],
#        'normal_as_attack': [17],
#        'attack_as_attack': [125],
#        'normal_as_normal': [453]},
#       'som_time': 0.007407188415527344,
#       'avg_time': 0.008322683612952072}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.611868143081665,
#       'avg_time': 5.181874318069287}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [66.85393258426966],
#        'fdr': [0.0],
#        'attack_as_normal': [295],
#        'normal_as_attack': [0],
#        'attack_as_attack': [125],
#        'normal_as_normal': [470]},
#       'combined_time': 0.7411594390869141,
#       'avg_time': 0.8327634147043979}],
#     'som_d_threshold': [0.045100460280380186]},
#    'norm mean cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [63.033707865168545],
#        'fdr': [11.764705882352944],
#        'attack_as_normal': [315],
#        'normal_as_attack': [14],
#        'attack_as_attack': [105],
#        'normal_as_normal': [456]},
#       'som_time': 0.015156745910644531,
#       'avg_time': 0.017030051584993856}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.5900256633758545,
#       'avg_time': 5.157332206040286}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [64.60674157303372],
#        'fdr': [0.0],
#        'attack_as_normal': [315],
#        'normal_as_attack': [0],
#        'attack_as_attack': [105],
#        'normal_as_normal': [470]},
#       'combined_time': 0.6257364749908447,
#       'avg_time': 0.7030746910009491}],
#     'som_d_threshold': [0.004053160591498434]},
#    'norm median euclidean': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [78.31460674157303],
#        'fdr': [10.45296167247387],
#        'attack_as_normal': [163],
#        'normal_as_attack': [30],
#        'attack_as_attack': [257],
#        'normal_as_normal': [440]},
#       'som_time': 0.005517005920410156,
#       'avg_time': 0.006198883056640625}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.602285385131836,
#       'avg_time': 5.171107174305433}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [81.68539325842697],
#        'fdr': [0.0],
#        'attack_as_normal': [163],
#        'normal_as_attack': [0],
#        'attack_as_attack': [257],
#        'normal_as_normal': [470]},
#       'combined_time': 1.6278002262115479,
#       'avg_time': 1.8289890182152224}],
#     'som_d_threshold': [0.038616274101114026]},
#    'norm median manhattan': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [77.86516853932585],
#        'fdr': [10.320284697508896],
#        'attack_as_normal': [168],
#        'normal_as_attack': [29],
#        'attack_as_attack': [252],
#        'normal_as_normal': [441]},
#       'som_time': 0.0072591304779052734,
#       'avg_time': 0.008156326379668847}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.63534951210022,
#       'avg_time': 5.208257878764292}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [81.12359550561797],
#        'fdr': [0.0],
#        'attack_as_normal': [168],
#        'normal_as_attack': [0],
#        'attack_as_attack': [252],
#        'normal_as_normal': [470]},
#       'combined_time': 1.4458184242248535,
#       'avg_time': 1.6245150833987116}],
#     'som_d_threshold': [0.07381749986386]},
#    'norm median chebyshev': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [78.20224719101122],
#        'fdr': [10.48951048951049],
#        'attack_as_normal': [164],
#        'normal_as_attack': [30],
#        'attack_as_attack': [256],
#        'normal_as_normal': [440]},
#       'som_time': 0.0068149566650390625,
#       'avg_time': 0.007657254679819171}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.568348169326782,
#       'avg_time': 5.132975471153688}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [81.57303370786518],
#        'fdr': [0.0],
#        'attack_as_normal': [164],
#        'normal_as_attack': [0],
#        'attack_as_attack': [256],
#        'normal_as_normal': [470]},
#       'combined_time': 1.4778072834014893,
#       'avg_time': 1.6604576217994262}],
#     'som_d_threshold': [0.02417217718039737]},
#    'norm median cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [73.82022471910112],
#        'fdr': [10.54852320675106],
#        'attack_as_normal': [208],
#        'normal_as_attack': [25],
#        'attack_as_attack': [212],
#        'normal_as_normal': [445]},
#       'som_time': 0.014551877975463867,
#       'avg_time': 0.016350424691532434}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.668238639831543,
#       'avg_time': 5.245211954866902}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [76.62921348314606],
#        'fdr': [0.0],
#        'attack_as_normal': [208],
#        'normal_as_attack': [0],
#        'attack_as_attack': [212],
#        'normal_as_normal': [470]},
#       'combined_time': 1.2930817604064941,
#       'avg_time': 1.4529008543893194}],
#     'som_d_threshold': [0.0011934046490293844]},
#    'norm convo avgpool laplacian mean euclidean': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.30337078651685],
#        'fdr': [52.75590551181102],
#        'attack_as_normal': [0],
#        'normal_as_attack': [469],
#        'attack_as_attack': [420],
#        'normal_as_normal': [1]},
#       'som_time': 0.005602359771728516,
#       'avg_time': 0.006294786260369118}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.5923850536346436,
#       'avg_time': 5.15998320633106}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.503250360488892,
#       'avg_time': 5.059831865717856}],
#     'som_d_threshold': [1.132058383964964]},
#    'norm convo avgpool laplacian mean manhattan': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [93.59550561797752],
#        'fdr': [10.284463894967178],
#        'attack_as_normal': [10],
#        'normal_as_attack': [47],
#        'attack_as_attack': [410],
#        'normal_as_normal': [423]},
#       'som_time': 0.007071971893310547,
#       'avg_time': 0.00794603583518039}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.527062654495239,
#       'avg_time': 5.086587252241842}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [98.87640449438202],
#        'fdr': [0.0],
#        'attack_as_normal': [10],
#        'normal_as_attack': [0],
#        'attack_as_attack': [410],
#        'normal_as_normal': [470]},
#       'combined_time': 2.325554847717285,
#       'avg_time': 2.612982974963242}],
#     'som_d_threshold': [1.4892323881645786]},
#    'norm convo avgpool laplacian mean chebyshev': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.19101123595505],
#        'fdr': [52.80898876404494],
#        'attack_as_normal': [0],
#        'normal_as_attack': [470],
#        'attack_as_attack': [420],
#        'normal_as_normal': [0]},
#       'som_time': 0.006697654724121094,
#       'avg_time': 0.007525454746203476}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.655754089355469,
#       'avg_time': 5.231184370062325}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.623831510543823,
#       'avg_time': 5.195316303981825}],
#     'som_d_threshold': [-0.013277495250488863]},
#    'norm convo avgpool laplacian mean cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.30337078651685],
#        'fdr': [52.75590551181102],
#        'attack_as_normal': [0],
#        'normal_as_attack': [469],
#        'attack_as_attack': [420],
#        'normal_as_normal': [1]},
#       'som_time': 0.015168905258178711,
#       'avg_time': 0.017043713773234506}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.6326377391815186,
#       'avg_time': 5.205210942900583}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.624390125274658,
#       'avg_time': 5.195943960982762}],
#     'som_d_threshold': [1.1725104968516975]},
#    'norm convo avgpool laplacian median euclidean': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.19101123595505],
#        'fdr': [52.80898876404494],
#        'attack_as_normal': [0],
#        'normal_as_attack': [470],
#        'attack_as_attack': [420],
#        'normal_as_normal': [0]},
#       'som_time': 0.005658149719238281,
#       'avg_time': 0.006357471594649755}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.917803525924683,
#       'avg_time': 5.5256219392412165}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.834836959838867,
#       'avg_time': 5.432401078470637}],
#     'som_d_threshold': [0.09162141908838066]},
#    'norm convo avgpool laplacian median manhattan': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [93.48314606741573],
#        'fdr': [10.307017543859654],
#        'attack_as_normal': [11],
#        'normal_as_attack': [47],
#        'attack_as_attack': [409],
#        'normal_as_normal': [423]},
#       'som_time': 0.006968975067138672,
#       'avg_time': 0.007830309064200755}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.676808595657349,
#       'avg_time': 5.254841118716121}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [98.76404494382022],
#        'fdr': [0.0],
#        'attack_as_normal': [11],
#        'normal_as_attack': [0],
#        'attack_as_attack': [409],
#        'normal_as_normal': [470]},
#       'combined_time': 2.4013795852661133,
#       'avg_time': 2.698179309287768}],
#     'som_d_threshold': [1.0611699008740918]},
#    'norm convo avgpool laplacian median chebyshev': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.19101123595505],
#        'fdr': [52.80898876404494],
#        'attack_as_normal': [0],
#        'normal_as_attack': [470],
#        'attack_as_attack': [420],
#        'normal_as_normal': [0]},
#       'som_time': 0.007233142852783203,
#       'avg_time': 0.008127126800880005}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.69694447517395,
#       'avg_time': 5.27746570244264}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.8417980670928955,
#       'avg_time': 5.440222547295389}],
#     'som_d_threshold': [0.034496864739362774]},
#    'norm convo avgpool laplacian median cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.30337078651685],
#        'fdr': [52.75590551181102],
#        'attack_as_normal': [0],
#        'normal_as_attack': [469],
#        'attack_as_attack': [420],
#        'normal_as_normal': [1]},
#       'som_time': 0.014867305755615234,
#       'avg_time': 0.016704837927657566}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.588112115859985,
#       'avg_time': 5.155182152651668}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.603711366653442,
#       'avg_time': 5.172709400734204}],
#     'som_d_threshold': [1.1858699273092412]},
#    'norm convo avgpool gaussian mean euclidean': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [64.26966292134831],
#        'fdr': [11.363636363636365],
#        'attack_as_normal': [303],
#        'normal_as_attack': [15],
#        'attack_as_attack': [117],
#        'normal_as_normal': [455]},
#       'som_time': 0.005519390106201172,
#       'avg_time': 0.006201561917079968}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.5577006340026855,
#       'avg_time': 5.121011948317624}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [65.95505617977528],
#        'fdr': [0.0],
#        'attack_as_normal': [303],
#        'normal_as_attack': [0],
#        'attack_as_attack': [117],
#        'normal_as_normal': [470]},
#       'combined_time': 0.685124397277832,
#       'avg_time': 0.7698026935705977}],
#     'som_d_threshold': [0.168768382837857]},
#    'norm convo avgpool gaussian mean manhattan': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [66.06741573033707],
#        'fdr': [11.184210526315786],
#        'attack_as_normal': [285],
#        'normal_as_attack': [17],
#        'attack_as_attack': [135],
#        'normal_as_normal': [453]},
#       'som_time': 0.007021188735961914,
#       'avg_time': 0.007888976107822377}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.63299560546875,
#       'avg_time': 5.205613039852528}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [67.97752808988764],
#        'fdr': [0.0],
#        'attack_as_normal': [285],
#        'normal_as_attack': [0],
#        'attack_as_attack': [135],
#        'normal_as_normal': [470]},
#       'combined_time': 0.7858262062072754,
#       'avg_time': 0.8829507934913207}],
#     'som_d_threshold': [0.27225723471927443]},
#    'norm convo avgpool gaussian mean chebyshev': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [57.640449438202246],
#        'fdr': [10.909090909090914],
#        'attack_as_normal': [371],
#        'normal_as_attack': [6],
#        'attack_as_attack': [49],
#        'normal_as_normal': [464]},
#       'som_time': 0.007037639617919922,
#       'avg_time': 0.007907460244853844}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.570868492126465,
#       'avg_time': 5.135807294524118}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [58.31460674157304],
#        'fdr': [0.0],
#        'attack_as_normal': [371],
#        'normal_as_attack': [0],
#        'attack_as_attack': [49],
#        'normal_as_normal': [470]},
#       'combined_time': 0.31430768966674805,
#       'avg_time': 0.3531547074907282}],
#     'som_d_threshold': [0.16391329341961733]},
#    'norm convo avgpool gaussian mean cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [62.58426966292134],
#        'fdr': [12.173913043478258],
#        'attack_as_normal': [319],
#        'normal_as_attack': [14],
#        'attack_as_attack': [101],
#        'normal_as_normal': [456]},
#       'som_time': 0.014711380004882812,
#       'avg_time': 0.016529640454924506}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.642007827758789,
#       'avg_time': 5.215739132313246}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [64.15730337078651],
#        'fdr': [0.0],
#        'attack_as_normal': [319],
#        'normal_as_attack': [0],
#        'attack_as_attack': [101],
#        'normal_as_normal': [470]},
#       'combined_time': 0.6040351390838623,
#       'avg_time': 0.6786911675099576}],
#     'som_d_threshold': [0.004335462909915853]},
#    'norm convo avgpool gaussian median euclidean': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [76.51685393258427],
#        'fdr': [10.486891385767795],
#        'attack_as_normal': [181],
#        'normal_as_attack': [28],
#        'attack_as_attack': [239],
#        'normal_as_normal': [442]},
#       'som_time': 0.007492542266845703,
#       'avg_time': 0.008418586816680564}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.581394672393799,
#       'avg_time': 5.1476344633638185}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [79.66292134831461],
#        'fdr': [0.0],
#        'attack_as_normal': [181],
#        'normal_as_attack': [0],
#        'attack_as_attack': [239],
#        'normal_as_normal': [470]},
#       'combined_time': 1.5719504356384277,
#       'avg_time': 1.7662364445375593}],
#     'som_d_threshold': [0.06831448904874801]},
#    'norm convo avgpool gaussian median manhattan': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [76.74157303370787],
#        'fdr': [9.811320754716979],
#        'attack_as_normal': [181],
#        'normal_as_attack': [26],
#        'attack_as_attack': [239],
#        'normal_as_normal': [444]},
#       'som_time': 0.009073734283447266,
#       'avg_time': 0.010195207060053108}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.932866811752319,
#       'avg_time': 5.542546979496987}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [79.66292134831461],
#        'fdr': [0.0],
#        'attack_as_normal': [181],
#        'normal_as_attack': [0],
#        'attack_as_attack': [239],
#        'normal_as_normal': [470]},
#       'combined_time': 1.3857288360595703,
#       'avg_time': 1.5569986922017645}],
#     'som_d_threshold': [0.12774631588522495]},
#    'norm convo avgpool gaussian median chebyshev': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [66.29213483146067],
#        'fdr': [11.538461538461542],
#        'attack_as_normal': [282],
#        'normal_as_attack': [18],
#        'attack_as_attack': [138],
#        'normal_as_normal': [452]},
#       'som_time': 0.007121562957763672,
#       'avg_time': 0.008001756132318731}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.847194671630859,
#       'avg_time': 5.446286147899842}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [68.31460674157303],
#        'fdr': [0.0],
#        'attack_as_normal': [282],
#        'normal_as_attack': [0],
#        'attack_as_attack': [138],
#        'normal_as_normal': [470]},
#       'combined_time': 0.860872745513916,
#       'avg_time': 0.967272747768445}],
#     'som_d_threshold': [0.05741310155472027]},
#    'norm convo avgpool gaussian median cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [72.13483146067415],
#        'fdr': [10.909090909090914],
#        'attack_as_normal': [224],
#        'normal_as_attack': [24],
#        'attack_as_attack': [196],
#        'normal_as_normal': [446]},
#       'som_time': 0.01539301872253418,
#       'avg_time': 0.017295526654532784}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.6325013637542725,
#       'avg_time': 5.205057712083452}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [74.8314606741573],
#        'fdr': [0.0],
#        'attack_as_normal': [224],
#        'normal_as_attack': [0],
#        'attack_as_attack': [196],
#        'normal_as_normal': [470]},
#       'combined_time': 1.1798036098480225,
#       'avg_time': 1.3256220335371038}],
#     'som_d_threshold': [0.0013047275889135745]},
#    'norm convo maxpool laplacian mean euclidean': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.30337078651685],
#        'fdr': [52.75590551181102],
#        'attack_as_normal': [0],
#        'normal_as_attack': [469],
#        'attack_as_attack': [420],
#        'normal_as_normal': [1]},
#       'som_time': 0.005590677261352539,
#       'avg_time': 0.006281659844216337}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.641404390335083,
#       'avg_time': 5.2150611127360476}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.609630823135376,
#       'avg_time': 5.179360475433007}],
#     'som_d_threshold': [1.1500839169617616]},
#    'norm convo maxpool laplacian mean manhattan': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [93.59550561797752],
#        'fdr': [10.284463894967178],
#        'attack_as_normal': [10],
#        'normal_as_attack': [47],
#        'attack_as_attack': [410],
#        'normal_as_normal': [423]},
#       'som_time': 0.006887197494506836,
#       'avg_time': 0.007738424151131277}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.690680742263794,
#       'avg_time': 5.270427800296398}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [98.87640449438202],
#        'fdr': [0.0],
#        'attack_as_normal': [10],
#        'normal_as_attack': [0],
#        'attack_as_attack': [410],
#        'normal_as_normal': [470]},
#       'combined_time': 2.4710006713867188,
#       'avg_time': 2.776405248749122}],
#     'som_d_threshold': [1.5080851816266043]},
#    'norm convo maxpool laplacian mean chebyshev': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.19101123595505],
#        'fdr': [52.80898876404494],
#        'attack_as_normal': [0],
#        'normal_as_attack': [470],
#        'attack_as_attack': [420],
#        'normal_as_normal': [0]},
#       'som_time': 0.007116794586181641,
#       'avg_time': 0.007996398411440045}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.627517223358154,
#       'avg_time': 5.199457554335005}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.701070785522461,
#       'avg_time': 5.282102006205013}],
#     'som_d_threshold': [0.056530209291160934]},
#    'norm convo maxpool laplacian mean cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.30337078651685],
#        'fdr': [52.75590551181102],
#        'attack_as_normal': [0],
#        'normal_as_attack': [469],
#        'attack_as_attack': [420],
#        'normal_as_normal': [1]},
#       'som_time': 0.01481938362121582,
#       'avg_time': 0.016650992832826762}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.627463102340698,
#       'avg_time': 5.199396744203032}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.657397508621216,
#       'avg_time': 5.233030908563164}],
#     'som_d_threshold': [1.1193688507744655]},
#    'norm convo maxpool laplacian median euclidean': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.19101123595505],
#        'fdr': [52.80898876404494],
#        'attack_as_normal': [0],
#        'normal_as_attack': [470],
#        'attack_as_attack': [420],
#        'normal_as_normal': [0]},
#       'som_time': 0.0055522918701171875,
#       'avg_time': 0.006238530191142908}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.638757705688477,
#       'avg_time': 5.2120873097623335}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.718730688095093,
#       'avg_time': 5.301944593365273}],
#     'som_d_threshold': [-0.09073282111108928]},
#    'norm convo maxpool laplacian median manhattan': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [93.59550561797752],
#        'fdr': [10.284463894967178],
#        'attack_as_normal': [10],
#        'normal_as_attack': [47],
#        'attack_as_attack': [410],
#        'normal_as_normal': [423]},
#       'som_time': 0.007042884826660156,
#       'avg_time': 0.007913353737820402}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.677555799484253,
#       'avg_time': 5.255680673577812}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [98.87640449438202],
#        'fdr': [0.0],
#        'attack_as_normal': [10],
#        'normal_as_attack': [0],
#        'attack_as_attack': [410],
#        'normal_as_normal': [470]},
#       'combined_time': 2.3451733589172363,
#       'avg_time': 2.6350262459744225}],
#     'som_d_threshold': [1.057235514896206]},
#    'norm convo maxpool laplacian median chebyshev': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.19101123595505],
#        'fdr': [52.80898876404494],
#        'attack_as_normal': [0],
#        'normal_as_attack': [470],
#        'attack_as_attack': [420],
#        'normal_as_normal': [0]},
#       'som_time': 0.006802558898925781,
#       'avg_time': 0.007643324605534585}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.5649354457855225,
#       'avg_time': 5.129140950320812}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.569716215133667,
#       'avg_time': 5.134512601273784}],
#     'som_d_threshold': [0.03362591897004491]},
#    'norm convo maxpool laplacian median cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [47.30337078651685],
#        'fdr': [52.75590551181102],
#        'attack_as_normal': [0],
#        'normal_as_attack': [469],
#        'attack_as_attack': [420],
#        'normal_as_normal': [1]},
#       'som_time': 0.01500844955444336,
#       'avg_time': 0.016863426465666697}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.533441781997681,
#       'avg_time': 5.0937548112333495}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'combined_time': 4.508919715881348,
#       'avg_time': 5.066201927956571}],
#     'som_d_threshold': [1.082411132059771]},
#    'norm convo maxpool gaussian mean euclidean': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [60.89887640449439],
#        'fdr': [12.5],
#        'attack_as_normal': [336],
#        'normal_as_attack': [12],
#        'attack_as_attack': [84],
#        'normal_as_normal': [458]},
#       'som_time': 0.005764484405517578,
#       'avg_time': 0.00647694877024447}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.541602611541748,
#       'avg_time': 5.102924282631178}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [62.247191011235955],
#        'fdr': [0.0],
#        'attack_as_normal': [336],
#        'normal_as_attack': [0],
#        'attack_as_attack': [84],
#        'normal_as_normal': [470]},
#       'combined_time': 0.49681711196899414,
#       'avg_time': 0.5582214741224654}],
#     'som_d_threshold': [0.17320564872368083]},
#    'norm convo maxpool gaussian mean manhattan': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [62.022471910112365],
#        'fdr': [12.037037037037035],
#        'attack_as_normal': [325],
#        'normal_as_attack': [13],
#        'attack_as_attack': [95],
#        'normal_as_normal': [457]},
#       'som_time': 0.007228374481201172,
#       'avg_time': 0.008121769080001317}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 5.233625650405884,
#       'avg_time': 5.880478258883016}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [63.48314606741573],
#        'fdr': [0.0],
#        'attack_as_normal': [325],
#        'normal_as_attack': [0],
#        'attack_as_attack': [95],
#        'normal_as_normal': [470]},
#       'combined_time': 0.5859308242797852,
#       'avg_time': 0.6583492407638035}],
#     'som_d_threshold': [0.306537534856809]},
#    'norm convo maxpool gaussian mean chebyshev': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [57.640449438202246],
#        'fdr': [10.909090909090914],
#        'attack_as_normal': [371],
#        'normal_as_attack': [6],
#        'attack_as_attack': [49],
#        'normal_as_normal': [464]},
#       'som_time': 0.007487058639526367,
#       'avg_time': 0.008412425437670075}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.802187442779541,
#       'avg_time': 5.395716227842181}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [58.31460674157304],
#        'fdr': [0.0],
#        'attack_as_normal': [371],
#        'normal_as_attack': [0],
#        'attack_as_attack': [49],
#        'normal_as_normal': [470]},
#       'combined_time': 0.3047490119934082,
#       'avg_time': 0.3424146202173126}],
#     'som_d_threshold': [0.15123121777740473]},
#    'norm convo maxpool gaussian mean cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [60.78651685393258],
#        'fdr': [12.631578947368416],
#        'attack_as_normal': [337],
#        'normal_as_attack': [12],
#        'attack_as_attack': [83],
#        'normal_as_normal': [458]},
#       'som_time': 0.014735698699951172,
#       'avg_time': 0.016556964831405813}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.597720384597778,
#       'avg_time': 5.165977960222222}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [62.13483146067416],
#        'fdr': [0.0],
#        'attack_as_normal': [337],
#        'normal_as_attack': [0],
#        'attack_as_attack': [83],
#        'normal_as_normal': [470]},
#       'combined_time': 0.5070624351501465,
#       'avg_time': 0.5697330732024118}],
#     'som_d_threshold': [0.005699131098609491]},
#    'norm convo maxpool gaussian median euclidean': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [68.65168539325842],
#        'fdr': [11.049723756906083],
#        'attack_as_normal': [259],
#        'normal_as_attack': [20],
#        'attack_as_attack': [161],
#        'normal_as_normal': [450]},
#       'som_time': 0.005639076232910156,
#       'avg_time': 0.006336040711135007}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.595370531082153,
#       'avg_time': 5.163337675373206}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [70.89887640449439],
#        'fdr': [0.0],
#        'attack_as_normal': [259],
#        'normal_as_attack': [0],
#        'attack_as_attack': [161],
#        'normal_as_normal': [470]},
#       'combined_time': 0.9296443462371826,
#       'avg_time': 1.0445442092552615}],
#     'som_d_threshold': [0.06756286731317662]},
#    'norm convo maxpool gaussian median manhattan': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [68.65168539325842],
#        'fdr': [10.169491525423723],
#        'attack_as_normal': [261],
#        'normal_as_attack': [18],
#        'attack_as_attack': [159],
#        'normal_as_normal': [452]},
#       'som_time': 0.007269382476806641,
#       'avg_time': 0.008167845479558023}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.582202434539795,
#       'avg_time': 5.1485420612806685}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [70.67415730337079],
#        'fdr': [0.0],
#        'attack_as_normal': [261],
#        'normal_as_attack': [0],
#        'attack_as_attack': [159],
#        'normal_as_normal': [470]},
#       'combined_time': 0.9406459331512451,
#       'avg_time': 1.0569055428665677}],
#     'som_d_threshold': [0.13929733675286673]},
#    'norm convo maxpool gaussian median chebyshev': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [67.97752808988764],
#        'fdr': [11.428571428571432],
#        'attack_as_normal': [265],
#        'normal_as_attack': [20],
#        'attack_as_attack': [155],
#        'normal_as_normal': [450]},
#       'som_time': 0.006762981414794922,
#       'avg_time': 0.007598855522241485}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.528457403182983,
#       'avg_time': 5.088154385598858}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [70.2247191011236],
#        'fdr': [0.0],
#        'attack_as_normal': [265],
#        'normal_as_attack': [0],
#        'attack_as_attack': [155],
#        'normal_as_normal': [470]},
#       'combined_time': 0.9035978317260742,
#       'avg_time': 1.0152784626135665}],
#     'som_d_threshold': [0.039282763150253586]},
#    'norm convo maxpool gaussian median cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [67.75280898876404],
#        'fdr': [11.111111111111116],
#        'attack_as_normal': [268],
#        'normal_as_attack': [19],
#        'attack_as_attack': [152],
#        'normal_as_normal': [451]},
#       'som_time': 0.016262292861938477,
#       'avg_time': 0.01827223917071739}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [100.0],
#        'fdr': [0.0],
#        'attack_as_normal': [0],
#        'normal_as_attack': [0],
#        'attack_as_attack': [420],
#        'normal_as_normal': [470]},
#       'rf_time': 4.551724195480347,
#       'avg_time': 5.1142968488543215}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [69.88764044943821],
#        'fdr': [0.0],
#        'attack_as_normal': [268],
#        'normal_as_attack': [0],
#        'attack_as_attack': [152],
#        'normal_as_normal': [470]},
#       'combined_time': 0.8845343589782715,
#       'avg_time': 0.9938588303126645}],
#     'som_d_threshold': [0.0019850145431694888]},
#    'tanh mean euclidean': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [92.35955056179776],
#        'fdr': [10.18099547511312],
#        'attack_as_normal': [23],
#        'normal_as_attack': [45],
#        'attack_as_attack': [397],
#        'normal_as_normal': [425]},
#       'som_time': 0.008537530899047852,
#       'avg_time': 0.009592731347244777}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [99.8876404494382],
#        'fdr': [0.0],
#        'attack_as_normal': [1],
#        'normal_as_attack': [0],
#        'attack_as_attack': [419],
#        'normal_as_normal': [470]},
#       'rf_time': 4.608485460281372,
#       'avg_time': 5.178073550877945}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [97.41573033707866],
#        'fdr': [0.0],
#        'attack_as_normal': [23],
#        'normal_as_attack': [0],
#        'attack_as_attack': [397],
#        'normal_as_normal': [470]},
#       'combined_time': 2.2907750606536865,
#       'avg_time': 2.5739045625322317}],
#     'som_d_threshold': [0.12546304577885384]},
#    'tanh mean manhattan': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [94.15730337078652],
#        'fdr': [6.8075117370892],
#        'attack_as_normal': [23],
#        'normal_as_attack': [29],
#        'attack_as_attack': [397],
#        'normal_as_normal': [441]},
#       'som_time': 0.006800651550292969,
#       'avg_time': 0.00764118151718311}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [99.8876404494382],
#        'fdr': [0.0],
#        'attack_as_normal': [1],
#        'normal_as_attack': [0],
#        'attack_as_attack': [419],
#        'normal_as_normal': [470]},
#       'rf_time': 4.629262447357178,
#       'avg_time': 5.201418480176605}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [97.41573033707866],
#        'fdr': [0.0],
#        'attack_as_normal': [23],
#        'normal_as_attack': [0],
#        'attack_as_attack': [397],
#        'normal_as_normal': [470]},
#       'combined_time': 2.20580792427063,
#       'avg_time': 2.4784358699669995}],
#     'som_d_threshold': [0.2645348489672254]},
#    'tanh mean chebyshev': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [85.50561797752809],
#        'fdr': [17.303370786516858],
#        'attack_as_normal': [52],
#        'normal_as_attack': [77],
#        'attack_as_attack': [368],
#        'normal_as_normal': [393]},
#       'som_time': 0.0068242549896240234,
#       'avg_time': 0.00766770223553261}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [99.8876404494382],
#        'fdr': [0.0],
#        'attack_as_normal': [1],
#        'normal_as_attack': [0],
#        'attack_as_attack': [419],
#        'normal_as_normal': [470]},
#       'rf_time': 4.592411518096924,
#       'avg_time': 5.160012941681937}],
#     'combined_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [94.15730337078652],
#        'fdr': [0.0],
#        'attack_as_normal': [52],
#        'normal_as_attack': [0],
#        'attack_as_attack': [368],
#        'normal_as_normal': [470]},
#       'combined_time': 2.324169874191284,
#       'avg_time': 2.6114268249340276}],
#     'som_d_threshold': [0.09322337336265454]},
#    'tanh mean cosine': {'som_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [93.37078651685393],
#        'fdr': [8.695652173913048],
#        'attack_as_normal': [21],
#        'normal_as_attack': [38],
#        'attack_as_attack': [399],
#        'normal_as_normal': [432]},
#       'som_time': 0.018102407455444336,
#       'avg_time': 0.020339783657802625}],
#     'rf_values': [{'evaluation1': {'com': ['self made data'],
#        'accuracy': [99.8876404494382],
#        'fdr': [0.0],
# ...
#        'fdr': [0.0],
#        'attack_as_normal': [1225],
#        'normal_as_attack': [0],
#        'attack_as_attack': [3],
#        'normal_as_normal': [600]},
#       'combined_time': 0.030665159225463867,
#       'avg_time': 0.016775251217431}],
#     'som_d_threshold': [0.9533808652331509]},
#    'tanh convo maxpool laplacian mean cosine': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [67.17724288840262],
#        'fdr': [32.822757111597376],
#        'attack_as_normal': [0],
#        'normal_as_attack': [600],
#        'attack_as_attack': [1228],
#        'normal_as_normal': [0]},
#       'som_time': 0.030251741409301758,
#       'avg_time': 0.016549092674672736}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.499535083770752,
#       'avg_time': 5.19668221212842}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'combined_time': 9.610552549362183,
#       'avg_time': 5.2574138672659645}],
#     'som_d_threshold': [-0.0324221279985387]},
#    'tanh convo maxpool laplacian median euclidean': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [94.42013129102844],
#        'fdr': [6.692307692307697],
#        'attack_as_normal': [15],
#        'normal_as_attack': [87],
#        'attack_as_attack': [1213],
#        'normal_as_normal': [513]},
#       'som_time': 0.011377096176147461,
#       'avg_time': 0.0062237944070828565}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.530515432357788,
#       'avg_time': 5.2136298864101684}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [98.96061269146608],
#        'fdr': [0.0],
#        'attack_as_normal': [19],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1209],
#        'normal_as_normal': [600]},
#       'combined_time': 6.955135345458984,
#       'avg_time': 3.8047786353714357}],
#     'som_d_threshold': [1.2099699764450518]},
#    'tanh convo maxpool laplacian median manhattan': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [94.52954048140045],
#        'fdr': [6.414219474497685],
#        'attack_as_normal': [17],
#        'normal_as_attack': [83],
#        'attack_as_attack': [1211],
#        'normal_as_normal': [517]},
#       'som_time': 0.01390838623046875,
#       'avg_time': 0.007608526384282686}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.546624422073364,
#       'avg_time': 5.222442244022629}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [98.85120350109409],
#        'fdr': [0.0],
#        'attack_as_normal': [21],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1207],
#        'normal_as_normal': [600]},
#       'combined_time': 6.773846626281738,
#       'avg_time': 3.7056053754276466}],
#     'som_d_threshold': [2.9706938893918613]},
#    'tanh convo maxpool laplacian median chebyshev': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [92.34135667396062],
#        'fdr': [9.463487332339792],
#        'attack_as_normal': [13],
#        'normal_as_attack': [127],
#        'attack_as_attack': [1215],
#        'normal_as_normal': [473]},
#       'som_time': 0.013838529586791992,
#       'avg_time': 0.007570311590148792}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.586936473846436,
#       'avg_time': 5.244494788756255}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [98.96061269146608],
#        'fdr': [0.0],
#        'attack_as_normal': [19],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1209],
#        'normal_as_normal': [600]},
#       'combined_time': 6.98391056060791,
#       'avg_time': 3.8205200003325546}],
#     'som_d_threshold': [0.5317110969800457]},
#    'tanh convo maxpool laplacian median cosine': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [67.17724288840262],
#        'fdr': [32.822757111597376],
#        'attack_as_normal': [0],
#        'normal_as_attack': [600],
#        'attack_as_attack': [1228],
#        'normal_as_normal': [0]},
#       'som_time': 0.030116796493530273,
#       'avg_time': 0.01647527160477586}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.509258031845093,
#       'avg_time': 5.202001111512633}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'combined_time': 9.722673416137695,
#       'avg_time': 5.3187491335545385}],
#     'som_d_threshold': [-0.010192896652136706]},
#    'tanh convo maxpool gaussian mean euclidean': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [94.69365426695843],
#        'fdr': [6.264501160092806],
#        'attack_as_normal': [16],
#        'normal_as_attack': [81],
#        'attack_as_attack': [1212],
#        'normal_as_normal': [519]},
#       'som_time': 0.011309623718261719,
#       'avg_time': 0.00618688387213442}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.605714321136475,
#       'avg_time': 5.2547671341009154}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [98.90590809628009],
#        'fdr': [0.0],
#        'attack_as_normal': [20],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1208],
#        'normal_as_normal': [600]},
#       'combined_time': 6.8825390338897705,
#       'avg_time': 3.7650651170075333}],
#     'som_d_threshold': [0.21266004778198058]},
#    'tanh convo maxpool gaussian mean manhattan': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [94.52954048140045],
#        'fdr': [6.414219474497685],
#        'attack_as_normal': [17],
#        'normal_as_attack': [83],
#        'attack_as_attack': [1211],
#        'normal_as_normal': [517]},
#       'som_time': 0.013726234436035156,
#       'avg_time': 0.007508880982513762}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.487292528152466,
#       'avg_time': 5.189984971637016}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [98.85120350109409],
#        'fdr': [0.0],
#        'attack_as_normal': [21],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1207],
#        'normal_as_normal': [600]},
#       'combined_time': 6.789672613143921,
#       'avg_time': 3.7142629174747928}],
#     'som_d_threshold': [0.4643717908299065]},
#    'tanh convo maxpool gaussian mean chebyshev': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [94.80306345733041],
#        'fdr': [5.982905982905984],
#        'attack_as_normal': [18],
#        'normal_as_attack': [77],
#        'attack_as_attack': [1210],
#        'normal_as_normal': [523]},
#       'som_time': 0.014011144638061523,
#       'avg_time': 0.007664739955175888}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.518552780151367,
#       'avg_time': 5.207085765947138}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [98.7964989059081],
#        'fdr': [0.0],
#        'attack_as_normal': [22],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1206],
#        'normal_as_normal': [600]},
#       'combined_time': 6.643088102340698,
#       'avg_time': 3.6340744542345176}],
#     'som_d_threshold': [0.13862844865655527]},
#    'tanh convo maxpool gaussian mean cosine': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [91.19256017505471],
#        'fdr': [2.7457927369353374],
#        'attack_as_normal': [130],
#        'normal_as_attack': [31],
#        'attack_as_attack': [1098],
#        'normal_as_normal': [569]},
#       'som_time': 0.03007054328918457,
#       'avg_time': 0.01644996897657799}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.506329536437988,
#       'avg_time': 5.200399089955136}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [92.77899343544857],
#        'fdr': [0.0],
#        'attack_as_normal': [132],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1096],
#        'normal_as_normal': [600]},
#       'combined_time': 5.867625951766968,
#       'avg_time': 3.2098610239425422}],
#     'som_d_threshold': [0.005127931553286346]},
#    'tanh convo maxpool gaussian median euclidean': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [94.20131291028446],
#        'fdr': [6.912442396313367],
#        'attack_as_normal': [16],
#        'normal_as_attack': [90],
#        'attack_as_attack': [1212],
#        'normal_as_normal': [510]},
#       'som_time': 0.011546850204467773,
#       'avg_time': 0.006316657661087403}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.486608982086182,
#       'avg_time': 5.189611040528546}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [98.90590809628009],
#        'fdr': [0.0],
#        'attack_as_normal': [20],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1208],
#        'normal_as_normal': [600]},
#       'combined_time': 6.779775619506836,
#       'avg_time': 3.7088488071700416}],
#     'som_d_threshold': [0.13423946945943588]},
#    'tanh convo maxpool gaussian median manhattan': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [94.52954048140045],
#        'fdr': [6.414219474497685],
#        'attack_as_normal': [17],
#        'normal_as_attack': [83],
#        'attack_as_attack': [1211],
#        'normal_as_normal': [517]},
#       'som_time': 0.014566659927368164,
#       'avg_time': 0.007968632345387397}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.532410144805908,
#       'avg_time': 5.214666381184852}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [98.85120350109409],
#        'fdr': [0.0],
#        'attack_as_normal': [21],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1207],
#        'normal_as_normal': [600]},
#       'combined_time': 6.6975696086883545,
#       'avg_time': 3.6638783417332355}],
#     'som_d_threshold': [0.2628857398389225]},
#    'tanh convo maxpool gaussian median chebyshev': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [94.03719912472648],
#        'fdr': [7.257448433919023],
#        'attack_as_normal': [14],
#        'normal_as_attack': [95],
#        'attack_as_attack': [1214],
#        'normal_as_normal': [505]},
#       'som_time': 0.014073371887207031,
#       'avg_time': 0.007698781119916319}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.514180660247803,
#       'avg_time': 5.204694015452846}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [98.96061269146608],
#        'fdr': [0.0],
#        'attack_as_normal': [19],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1209],
#        'normal_as_normal': [600]},
#       'combined_time': 6.982594728469849,
#       'avg_time': 3.819800179688101}],
#     'som_d_threshold': [0.09993355801536564]},
#    'tanh convo maxpool gaussian median cosine': {'som_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [92.66958424507659],
#        'fdr': [8.995502248875564],
#        'attack_as_normal': [14],
#        'normal_as_attack': [120],
#        'attack_as_attack': [1214],
#        'normal_as_normal': [480]},
#       'som_time': 0.031058788299560547,
#       'avg_time': 0.01699058440894997}],
#     'rf_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [99.50765864332604],
#        'fdr': [0.0],
#        'attack_as_normal': [9],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1219],
#        'normal_as_normal': [600]},
#       'rf_time': 9.57384204864502,
#       'avg_time': 5.237331536457888}],
#     'combined_values': [{'evaluation1': {'com': ['filled 2s split with bandwidth caida 2007'],
#        'accuracy': [98.90590809628009],
#        'fdr': [0.0],
#        'attack_as_normal': [20],
#        'normal_as_attack': [0],
#        'attack_as_attack': [1208],
#        'normal_as_normal': [600]},
#       'combined_time': 7.117891311645508,
#       'avg_time': 3.893813627814829}],
#     'som_d_threshold': [0.0013979950820526038]}}]]

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[0][0][value]])
  value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[1][0][value]])
  value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[2][0][value]])
# Out:
# variation : [[tanh convo gaussian mean cosine]]
# ['self made data'] with [0.007010754604790339]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.3708 |   7.72834 |                 26 |                 33 |                394 |                437 |            0.0182695 |           0.0205276 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |            5.36625   |           6.02949   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.0787 |   0       |                 26 |                  0 |                394 |                470 |            2.68381   |           3.01552   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['self made data'] with [0.005739727593789745]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.4831 |   8.48624 |                 21 |                 37 |                399 |                433 |            0.0179894 |           0.0202128 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |            5.28314   |           5.93612   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.6404 |   0       |                 21 |                  0 |                399 |                470 |            2.67508   |           3.00571   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo gaussian mean cosine]]
# ['1s split with '] with [0.005182562815730184]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        96.1834 |   2.59679 |                 84 |                 55 |               2063 |               1440 |            0.0402241 |           0.0110445 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           20.9092    |           5.74113   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.6936 |   0       |                 84 |                  0 |               2063 |               1495 |           12.3146    |           3.38126   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['1s split with '] with [0.006289480875135589]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        96.2383 |   1.35528 |                109 |                 28 |               2038 |               1467 |            0.0400591 |           0.0109992 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           22.207     |           6.09749   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.0071 |   0       |                109 |                  0 |               2038 |               1495 |           12.0952    |           3.32104   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo gaussian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.004054681100684127]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        91.2473 |   4.82234 |                103 |                 57 |               1125 |                543 |            0.0382609 |           0.0209305 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           10.328     |           5.64991   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        94.1466 |   0       |                107 |                  0 |               1121 |                600 |            7.33291   |           4.01144   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.004927668881269758]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        91.4114 |   3.06748 |                122 |                 35 |               1106 |                565 |             0.037724 |           0.0206368 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |            10.3028   |           5.63612   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        93.2166 |   0       |                124 |                  0 |               1104 |                600 |             7.14469  |           3.90847   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[0][0][value]])
  value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[1][0][value]])
  value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[2][0][value]])
# Out:
# variation : [[tanh convo gaussian mean cosine]]
# ['self made data'] with [0.005386447665433697]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.2584 |   9.09091 |                 20 |                 40 |                400 |                430 |            0.0121098 |           0.0136065 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |            5.39264   |           6.05914   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.7528 |   0       |                 20 |                  0 |                400 |                470 |            3.08999   |           3.4719    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['self made data'] with [0.006800393174061097]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.5955 |   7.69231 |                 24 |                 33 |                396 |                437 |            0.0148981 |           0.0167394 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |            5.36567   |           6.02884   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.3034 |   0       |                 24 |                  0 |                396 |                470 |            2.68526   |           3.01715   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo gaussian mean cosine]]
# ['1s split with '] with [0.0052396951965915355]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        95.9088 |    2.5641 |                 95 |                 54 |               2052 |               1441 |            0.0407827 |           0.0111979 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           22.8222    |           6.2664    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.3915 |    0      |                 95 |                  0 |               2052 |               1495 |           13.53      |           3.715     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['1s split with '] with [0.006757109115042528]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        95.8539 |   1.17417 |                127 |                 24 |               2020 |               1471 |            0.0859911 |            0.023611 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           21.2541    |            5.83582  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        96.5129 |   0       |                127 |                  0 |               2020 |               1495 |           11.8822    |            3.26254  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo gaussian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.004423661556034809]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        89.9891 |   4.52567 |                131 |                 52 |               1097 |                548 |            0.0200195 |           0.0109516 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |            9.98853   |           5.46419   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        92.6149 |   0       |                135 |                  0 |               1093 |                600 |            6.69861   |           3.66445   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.004985065848165382]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        91.302  |   2.99033 |                125 |                 34 |               1103 |                566 |            0.0205011 |           0.0112151 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           10.2531    |           5.60892   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        93.0525 |   0       |                127 |                  0 |               1101 |                600 |            6.53492   |           3.5749    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[0][0][value]])
  value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[1][0][value]])
  value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[2][0][value]])
# Out:
# variation : [[tanh convo gaussian mean cosine]]
# ['self made data'] with [0.005482831809782804]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.3708 |   8.69565 |                 21 |                 38 |                399 |                432 |           0.00977802 |           0.0109865 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |           5.839      |           6.56067   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.6404 |   0       |                 21 |                  0 |                399 |                470 |           2.57407    |           2.89221   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['self made data'] with [0.005431075804645823]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.4831 |    8.6758 |                 20 |                 38 |                400 |                432 |            0.0105011 |            0.011799 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |            5.9041    |            6.63382  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.7528 |    0      |                 20 |                  0 |                400 |                470 |            2.4949    |            2.80326  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo gaussian mean cosine]]
# ['1s split with '] with [0.005198649841311617]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        96.101  |   2.60047 |                 87 |                 55 |               2060 |               1440 |            0.0433471 |            0.011902 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           21.9821    |            6.03573  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.6112 |   0       |                 87 |                  0 |               2060 |               1495 |           13.011     |            3.57248  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['1s split with '] with [0.006263490381553549]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        96.2658 |   1.35462 |                108 |                 28 |               2039 |               1467 |            0.0421271 |            0.011567 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           22.6341    |            6.21473  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.0346 |   0       |                108 |                  0 |               2039 |               1495 |           12.9231    |            3.54835  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo gaussian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.004351954004074417]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        90.2079 |   4.58874 |                126 |                 53 |               1102 |                547 |            0.0207243 |           0.0113371 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           10.5702    |           5.78238   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        92.8884 |   0       |                130 |                  0 |               1098 |                600 |            7.21573   |           3.94733   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.004920192009533412]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        91.3567 |   3.15236 |                122 |                 36 |               1106 |                564 |             0.021565 |            0.011797 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |            11.2965   |            6.1797   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        93.2166 |   0       |                124 |                  0 |               1104 |                600 |             6.89967  |            3.77444  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %% [markdown]
# ## All with distance

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[0][0][value]])
# Out:
# variation : [[norm mean euclidean]]
# ['self made data'] with [0.08043873807603849]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        64.4944 |   11.7647 |                300 |                 16 |                120 |                454 |            0.0126636 |           0.0142288 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |            4.71697   |           5.29996   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        66.2921 |    0      |                300 |                  0 |                120 |                470 |            0.709486  |           0.797175  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm mean manhattan]]
# ['self made data'] with [0.1631711399517969]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        64.382  |   11.2782 |                302 |                 15 |                118 |                455 |           0.00668883 |          0.00751554 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.63046    |          5.20276    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        66.0674 |    0      |                302 |                  0 |                118 |                470 |           0.688508   |          0.773604   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm mean chebyshev]]
# ['self made data'] with [0.045100460280380186]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        64.9438 |   11.9718 |                295 |                 17 |                125 |                453 |           0.00740719 |          0.00832268 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.61187    |          5.18187    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        66.8539 |    0      |                295 |                  0 |                125 |                470 |           0.741159   |          0.832763   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm mean cosine]]
# ['self made data'] with [0.004053160591498434]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        63.0337 |   11.7647 |                315 |                 14 |                105 |                456 |            0.0151567 |           0.0170301 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |            4.59003   |           5.15733   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        64.6067 |    0      |                315 |                  0 |                105 |                470 |            0.625736  |           0.703075  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median euclidean]]
# ['self made data'] with [0.038616274101114026]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        78.3146 |    10.453 |                163 |                 30 |                257 |                440 |           0.00551701 |          0.00619888 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |     0     |                  0 |                  0 |                420 |                470 |           4.60229    |          5.17111    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        81.6854 |     0     |                163 |                  0 |                257 |                470 |           1.6278     |          1.82899    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median manhattan]]
# ['self made data'] with [0.07381749986386]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        77.8652 |   10.3203 |                168 |                 29 |                252 |                441 |           0.00725913 |          0.00815633 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.63535    |          5.20826    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        81.1236 |    0      |                168 |                  0 |                252 |                470 |           1.44582    |          1.62452    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median chebyshev]]
# ['self made data'] with [0.02417217718039737]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        78.2022 |   10.4895 |                164 |                 30 |                256 |                440 |           0.00681496 |          0.00765725 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.56835    |          5.13298    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        81.573  |    0      |                164 |                  0 |                256 |                470 |           1.47781    |          1.66046    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median cosine]]
# ['self made data'] with [0.0011934046490293844]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        73.8202 |   10.5485 |                208 |                 25 |                212 |                445 |            0.0145519 |           0.0163504 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |            4.66824   |           5.24521   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        76.6292 |    0      |                208 |                  0 |                212 |                470 |            1.29308   |           1.4529    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean euclidean]]
# ['self made data'] with [1.132058383964964]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        47.3034 |   52.7559 |                  0 |                469 |                420 |                  1 |           0.00560236 |          0.00629479 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.59239    |          5.15998    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.50325    |          5.05983    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean manhattan]]
# ['self made data'] with [1.4892323881645786]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.5955 |   10.2845 |                 10 |                 47 |                410 |                423 |           0.00707197 |          0.00794604 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.52706    |          5.08659    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.8764 |    0      |                 10 |                  0 |                410 |                470 |           2.32555    |          2.61298    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean chebyshev]]
# ['self made data'] with [-0.013277495250488863]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |         47.191 |    52.809 |                  0 |                470 |                420 |                  0 |           0.00669765 |          0.00752545 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        100     |     0     |                  0 |                  0 |                420 |                470 |           4.65575    |          5.23118    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        100     |     0     |                  0 |                  0 |                420 |                470 |           4.62383    |          5.19532    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean cosine]]
# ['self made data'] with [1.1725104968516975]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        47.3034 |   52.7559 |                  0 |                469 |                420 |                  1 |            0.0151689 |           0.0170437 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |            4.63264   |           5.20521   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |                420 |                470 |            4.62439   |           5.19594   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median euclidean]]
# ['self made data'] with [0.09162141908838066]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |         47.191 |    52.809 |                  0 |                470 |                420 |                  0 |           0.00565815 |          0.00635747 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        100     |     0     |                  0 |                  0 |                420 |                470 |           4.9178     |          5.52562    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        100     |     0     |                  0 |                  0 |                420 |                470 |           4.83484    |          5.4324     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median manhattan]]
# ['self made data'] with [1.0611699008740918]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.4831 |    10.307 |                 11 |                 47 |                409 |                423 |           0.00696898 |          0.00783031 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |     0     |                  0 |                  0 |                420 |                470 |           4.67681    |          5.25484    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.764  |     0     |                 11 |                  0 |                409 |                470 |           2.40138    |          2.69818    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median chebyshev]]
# ['self made data'] with [0.034496864739362774]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |         47.191 |    52.809 |                  0 |                470 |                420 |                  0 |           0.00723314 |          0.00812713 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        100     |     0     |                  0 |                  0 |                420 |                470 |           4.69694    |          5.27747    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        100     |     0     |                  0 |                  0 |                420 |                470 |           4.8418     |          5.44022    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median cosine]]
# ['self made data'] with [1.1858699273092412]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        47.3034 |   52.7559 |                  0 |                469 |                420 |                  1 |            0.0148673 |           0.0167048 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |            4.58811   |           5.15518   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |                420 |                470 |            4.60371   |           5.17271   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean euclidean]]
# ['self made data'] with [0.168768382837857]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        64.2697 |   11.3636 |                303 |                 15 |                117 |                455 |           0.00551939 |          0.00620156 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.5577     |          5.12101    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        65.9551 |    0      |                303 |                  0 |                117 |                470 |           0.685124   |          0.769803   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean manhattan]]
# ['self made data'] with [0.27225723471927443]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        66.0674 |   11.1842 |                285 |                 17 |                135 |                453 |           0.00702119 |          0.00788898 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.633      |          5.20561    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        67.9775 |    0      |                285 |                  0 |                135 |                470 |           0.785826   |          0.882951   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean chebyshev]]
# ['self made data'] with [0.16391329341961733]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        57.6404 |   10.9091 |                371 |                  6 |                 49 |                464 |           0.00703764 |          0.00790746 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.57087    |          5.13581    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        58.3146 |    0      |                371 |                  0 |                 49 |                470 |           0.314308   |          0.353155   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean cosine]]
# ['self made data'] with [0.004335462909915853]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        62.5843 |   12.1739 |                319 |                 14 |                101 |                456 |            0.0147114 |           0.0165296 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |            4.64201   |           5.21574   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        64.1573 |    0      |                319 |                  0 |                101 |                470 |            0.604035  |           0.678691  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median euclidean]]
# ['self made data'] with [0.06831448904874801]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        76.5169 |   10.4869 |                181 |                 28 |                239 |                442 |           0.00749254 |          0.00841859 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.58139    |          5.14763    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        79.6629 |    0      |                181 |                  0 |                239 |                470 |           1.57195    |          1.76624    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median manhattan]]
# ['self made data'] with [0.12774631588522495]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        76.7416 |   9.81132 |                181 |                 26 |                239 |                444 |           0.00907373 |           0.0101952 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |                420 |                470 |           4.93287    |           5.54255   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        79.6629 |   0       |                181 |                  0 |                239 |                470 |           1.38573    |           1.557     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median chebyshev]]
# ['self made data'] with [0.05741310155472027]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        66.2921 |   11.5385 |                282 |                 18 |                138 |                452 |           0.00712156 |          0.00800176 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.84719    |          5.44629    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        68.3146 |    0      |                282 |                  0 |                138 |                470 |           0.860873   |          0.967273   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median cosine]]
# ['self made data'] with [0.0013047275889135745]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        72.1348 |   10.9091 |                224 |                 24 |                196 |                446 |             0.015393 |           0.0172955 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |             4.6325   |           5.20506   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        74.8315 |    0      |                224 |                  0 |                196 |                470 |             1.1798   |           1.32562   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean euclidean]]
# ['self made data'] with [1.1500839169617616]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        47.3034 |   52.7559 |                  0 |                469 |                420 |                  1 |           0.00559068 |          0.00628166 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.6414     |          5.21506    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |                420 |                470 |           4.60963    |          5.17936    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean manhattan]]
# ['self made data'] with [1.5080851816266043]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.5955 |   10.2845 |                 10 |                 47 |                410 |                423 |            0.0068872 |          0.00773842 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |            4.69068   |          5.27043    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.8764 |    0      |                 10 |                  0 |                410 |                470 |            2.471     |          2.77641    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean chebyshev]]
# ['self made data'] with [0.056530209291160934]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |         47.191 |    52.809 |                  0 |                470 |                420 |                  0 |           0.00711679 |           0.0079964 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        100     |     0     |                  0 |                  0 |                420 |                470 |           4.62752    |           5.19946   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        100     |     0     |                  0 |                  0 |                420 |                470 |           4.70107    |           5.2821    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean cosine]]
# ['self made data'] with [1.1193688507744655]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        47.3034 |   52.7559 |                  0 |                469 |                420 |                  1 |            0.0148194 |            0.016651 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |                420 |                470 |            4.62746   |            5.1994   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |                420 |                470 |            4.6574    |            5.23303  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian median euclidean]]
# ['self made data'] with [-0.09073282111108928]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |         47.191 |    52.809 |                  0 |                470 |                420 |                  0 |           0.00555229 |          0.00623853 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        100     |     0     |                  0 |                  0 |                420 |                470 |           4.63876    |          5.21209    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        100     |     0     |                  0 |                  0 |                420 |                470 |           4.71873    |          5.30194    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian median manhattan]]
# ['self made data'] with [1.057235514896206]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# ...
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        81.9101 |   27.7108 |                  0 |                161 |                420 |                309 |            0.0091958 |           0.0103324 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |            4.80594   |           5.39993   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |            3.07736   |           3.4577    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool laplacian median cosine]]
# ['self made data'] with [0.028167459673266313]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        47.191  |    52.809 |                  0 |                470 |                420 |                  0 |            0.0170748 |           0.0191852 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |     0     |                  1 |                  0 |                419 |                470 |            4.70039   |           5.28134   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.8876 |     0     |                  1 |                  0 |                419 |                470 |            4.72983   |           5.31441   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['self made data'] with [0.20375921661353066]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        89.3258 |   13.6465 |                 34 |                 61 |                386 |                409 |           0.00828671 |          0.00931092 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           4.65708    |          5.23268    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        96.1798 |    0      |                 34 |                  0 |                386 |                470 |           2.31839    |          2.60493    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean manhattan]]
# ['self made data'] with [0.24832738434209153]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        81.9101 |   27.7108 |                  0 |                161 |                420 |                309 |           0.00681615 |          0.00765859 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           4.60623    |          5.17554    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           3.05789    |          3.43583    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean chebyshev]]
# ['self made data'] with [0.0945951059019384]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        81.9101 |   27.7108 |                  0 |                161 |                420 |                309 |           0.00694251 |          0.00780057 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           4.55793    |          5.12127    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           3.00478    |          3.37615    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['self made data'] with [0.00534394171518706]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.5955 |   8.65604 |                 19 |                 38 |                401 |                432 |            0.0170205 |           0.0191241 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |            4.68616   |           5.26534   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.8652 |   0       |                 19 |                  0 |                401 |                470 |            2.35046   |           2.64096   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median euclidean]]
# ['self made data'] with [0.05695611392582525]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        81.9101 |   27.7108 |                  0 |                161 |                420 |                309 |           0.00589156 |          0.00661973 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           4.66937    |          5.24648    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           3.01028    |          3.38233    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median manhattan]]
# ['self made data'] with [0.08981438011353562]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        81.9101 |   27.7108 |                  0 |                161 |                420 |                309 |           0.00672555 |           0.0075568 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           4.57764    |           5.14342   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           3.02753    |           3.40172   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median chebyshev]]
# ['self made data'] with [0.042861250988102756]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        81.9101 |   27.7108 |                  0 |                161 |                420 |                309 |           0.00681996 |          0.00766288 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           4.57316    |          5.13838    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           3.02846    |          3.40276    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median cosine]]
# ['self made data'] with [0.005151808697115345]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        88.0899 |   14.6396 |                 41 |                 65 |                379 |                405 |            0.0165184 |           0.0185599 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |            4.64205   |           5.21578   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        95.3933 |    0      |                 41 |                  0 |                379 |                470 |            2.31155   |           2.59725   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[1][0][value]])
# Out:
# variation : [[norm mean euclidean]]
# ['1s split with '] with [0.005751751531754937]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        99.8902 |   0.18596 |                  0 |                  4 |               2147 |               1491 |            0.0224721 |          0.00617028 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           18.8297    |          5.17015    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           11.1328    |          3.05679    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm mean manhattan]]
# ['1s split with '] with [0.008921307840027797]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        99.9725 | 0.0465549 |                  0 |                  1 |               2147 |               1494 |            0.0279906 |           0.0076855 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      | 0         |                  0 |                  0 |               2147 |               1495 |           18.8048    |           5.16333   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      | 0         |                  0 |                  0 |               2147 |               1495 |           11.2541    |           3.09009   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm mean chebyshev]]
# ['1s split with '] with [0.005510792750888144]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        99.8627 |  0.139665 |                  2 |                  3 |               2145 |               1492 |            0.0288248 |          0.00791455 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |  0        |                  0 |                  0 |               2147 |               1495 |           19.1438    |          5.25639    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.9451 |  0        |                  2 |                  0 |               2145 |               1495 |           11.4255    |          3.13715    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm mean cosine]]
# ['1s split with '] with [6.404264059715718e-06]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        98.1604 |    3.0262 |                  0 |                 67 |               2147 |               1428 |            0.0656049 |           0.0180134 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           18.9612    |           5.20625   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           11.6627    |           3.20227   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median euclidean]]
# ['1s split with '] with [0.005508132480920117]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        99.8078 |  0.324977 |                  0 |                  7 |               2147 |               1488 |            0.0229034 |           0.0062887 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |  0        |                  0 |                  0 |               2147 |               1495 |           18.7894    |           5.15908   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |  0        |                  0 |                  0 |               2147 |               1495 |           11.1697    |           3.06691   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median manhattan]]
# ['1s split with '] with [0.008964175037002722]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        99.9725 | 0.0465549 |                  0 |                  1 |               2147 |               1494 |            0.0280676 |          0.00770664 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      | 0         |                  0 |                  0 |               2147 |               1495 |           19.0223    |          5.22305    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      | 0         |                  0 |                  0 |               2147 |               1495 |           11.172     |          3.06755    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median chebyshev]]
# ['1s split with '] with [0.005330623206697888]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        99.7803 |  0.325128 |                  1 |                  7 |               2146 |               1488 |              0.02775 |          0.00761944 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |  0        |                  0 |                  0 |               2147 |               1495 |             18.7732  |          5.15465    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.9725 |  0        |                  1 |                  0 |               2146 |               1495 |             11.199   |          3.07497    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median cosine]]
# ['1s split with '] with [-0.017104768435778774]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0600986 |           0.0165016 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           18.8393    |           5.1728    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.0868    |           5.24073   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean euclidean]]
# ['1s split with '] with [-0.023237756207705747]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |             0.022615 |          0.00620949 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |            18.9495   |          5.20306    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |            18.8673   |          5.18048    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean manhattan]]
# ['1s split with '] with [-0.004840081221352276]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0282545 |          0.00775797 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.0325    |          5.22584    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.1206    |          5.25004    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean chebyshev]]
# ['1s split with '] with [0.038730628657207083]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0285885 |          0.00784968 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.71      |          5.41187    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.6028    |          5.38242    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean cosine]]
# ['1s split with '] with [-0.006647102384662642]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0612581 |           0.0168199 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.0038    |           5.21797   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.0216    |           5.22284   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median euclidean]]
# ['1s split with '] with [-0.012194973079439756]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0225081 |          0.00618016 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.1408    |          5.25556    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.0298    |          5.2251     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median manhattan]]
# ['1s split with '] with [0.00931296785488024]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0280943 |          0.00771397 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           18.9991    |          5.21666    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           18.8018    |          5.16248    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median chebyshev]]
# ['1s split with '] with [-0.04396873582492551]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0294988 |          0.00809962 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.7862    |          5.43279    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.706     |          5.41078    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median cosine]]
# ['1s split with '] with [0.030162029801106667]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0606458 |           0.0166518 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           18.913     |           5.19302   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.0232    |           5.2233    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean euclidean]]
# ['1s split with '] with [0.0806730846251685]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0227256 |          0.00623986 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           18.9846    |          5.21269    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           18.7146    |          5.13855    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean manhattan]]
# ['1s split with '] with [0.13708610395361756]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        99.7254 |   0.32543 |                  3 |                  7 |               2144 |               1488 |            0.0292373 |          0.00802781 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           19.7446    |          5.42137    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.9176 |   0       |                  3 |                  0 |               2144 |               1495 |           11.4089    |          3.1326     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean chebyshev]]
# ['1s split with '] with [-0.12445946170770919]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |             0.027467 |          0.00754174 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |            18.9663   |          5.20766    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |            18.9325   |          5.19839    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean cosine]]
# ['1s split with '] with [0.0026528245742894405]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        41.0489 |         0 |               2147 |                  0 |                  0 |               1495 |             0.060364 |           0.0165744 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |         0 |                  0 |                  0 |               2147 |               1495 |            19.0286   |           5.22477   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        41.0489 |         0 |               2147 |                  0 |                  0 |               1495 |             0.063504 |           0.0174366 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median euclidean]]
# ['1s split with '] with [0.00446905931832664]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        99.1763 |   1.37804 |                  0 |                 30 |               2147 |               1465 |            0.0225947 |          0.00620392 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           19.0857    |          5.24044    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           11.5403    |          3.16868    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median manhattan]]
# ['1s split with '] with [0.0075871835944459134]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        99.5607 |  0.739713 |                  0 |                 16 |               2147 |               1479 |            0.0286133 |          0.00785649 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |  0        |                  0 |                  0 |               2147 |               1495 |           19.5947    |          5.3802     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |  0        |                  0 |                  0 |               2147 |               1495 |           11.6465    |          3.19783    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median chebyshev]]
# ['1s split with '] with [0.004941760352974056]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        99.6431 |  0.464253 |                  3 |                 10 |               2144 |               1485 |            0.0300207 |          0.00824292 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |  0        |                  0 |                  0 |               2147 |               1495 |           19.8251    |          5.44346    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.9176 |  0        |                  3 |                  0 |               2144 |               1495 |           11.5573    |          3.17334    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median cosine]]
# ['1s split with '] with [0.050446572561048245]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        41.0489 |         0 |               2147 |                  0 |                  0 |               1495 |            0.0613158 |           0.0168357 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |         0 |                  0 |                  0 |               2147 |               1495 |           19.2953    |           5.29799   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        41.0489 |         0 |               2147 |                  0 |                  0 |               1495 |            0.0641973 |           0.0176269 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean euclidean]]
# ['1s split with '] with [0.020093848705356597]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0239222 |          0.00656843 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.0651    |          5.23478    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.1282    |          5.25212    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean manhattan]]
# ['1s split with '] with [-0.022955579714031962]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0281396 |          0.00772641 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.1343    |          5.25379    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.4318    |          5.33548    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean chebyshev]]
# ['1s split with '] with [0.050387449972239415]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |             0.028599 |          0.00785256 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |            19.0965   |          5.24342    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |            19.8531   |          5.45116    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean cosine]]
# ['1s split with '] with [0.01721810436513045]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |             0.063652 |           0.0174772 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |            19.7274   |           5.41665   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |            19.6806   |           5.40379   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian median euclidean]]
# ['1s split with '] with [-0.004912332792176637]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |            0.0226965 |          0.00623188 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.3703    |          5.31858    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.2525    |          5.28625    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian median manhattan]]
# ['1s split with '] with [-0.023552152209114472]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# ...
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        90.4997 |   13.7626 |                  4 |                342 |               2143 |               1153 |            0.0280824 |           0.0077107 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           18.8316    |           5.17067   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.8902 |    0      |                  4 |                  0 |               2143 |               1495 |           12.838     |           3.525     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool laplacian median cosine]]
# ['1s split with '] with [0.020131258080283838]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        58.9511 |   41.0489 |                  0 |               1495 |               2147 |                  0 |             0.059613 |           0.0163682 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |            18.8086   |           5.16437   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |    0      |                  0 |                  0 |               2147 |               1495 |            18.9426   |           5.20114   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['1s split with '] with [0.1873746488434037]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        95.6617 |   6.77966 |                  2 |                156 |               2145 |               1339 |             0.022578 |          0.00619934 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |            19.0721   |          5.23672    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.9451 |   0       |                  2 |                  0 |               2145 |               1495 |            12.0833   |          3.31775    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean manhattan]]
# ['1s split with '] with [0.35269272372621796]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        95.3048 |   7.26644 |                  3 |                168 |               2144 |               1327 |            0.0322273 |          0.00884879 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           19.0743    |          5.23732    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.9176 |   0       |                  3 |                  0 |               2144 |               1495 |           12.1302    |          3.33064    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean chebyshev]]
# ['1s split with '] with [0.14949231400329782]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        96.2383 |   5.92105 |                  2 |                135 |               2145 |               1360 |            0.0290687 |          0.00798152 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           19.1556    |          5.25964    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.9451 |   0       |                  2 |                  0 |               2145 |               1495 |           12.087     |          3.31879    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['1s split with '] with [0.007258581702707614]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.8105 |  0.853414 |                172 |                 17 |               1975 |               1478 |            0.0605204 |           0.0166174 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |  0        |                  0 |                  0 |               2147 |               1495 |           19.1616    |           5.26128   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        95.2773 |  0        |                172 |                  0 |               1975 |               1495 |           10.5573    |           2.89877   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median euclidean]]
# ['1s split with '] with [0.11420075149235777]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.9204 |    7.7883 |                  4 |                181 |               2143 |               1314 |            0.0225723 |          0.00619777 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           19.0927    |          5.24236    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.8902 |    0      |                  4 |                  0 |               2143 |               1495 |           12.1218    |          3.32834    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median manhattan]]
# ['1s split with '] with [0.19666357784609728]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        95.2773 |   7.30653 |                  3 |                169 |               2144 |               1326 |            0.0289302 |          0.00794349 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           18.9491    |          5.20294    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.9176 |   0       |                  3 |                  0 |               2144 |               1495 |           12.147     |          3.33525    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median chebyshev]]
# ['1s split with '] with [0.09425558541691802]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |          95.14 |   7.61618 |                  0 |                177 |               2147 |               1318 |            0.0287724 |          0.00790015 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |         100    |   0       |                  0 |                  0 |               2147 |               1495 |           18.8729    |          5.18201    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |         100    |   0       |                  0 |                  0 |               2147 |               1495 |           12.0913    |          3.31997    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median cosine]]
# ['1s split with '] with [0.0018920178757549679]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.2614 |   8.87097 |                  0 |                209 |               2147 |               1286 |            0.0602305 |           0.0165378 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           18.8791    |           5.18371   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           12.4857    |           3.42826   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[2][0][value]])
# Out:
# variation : [[norm mean euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.0007324236275574797]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        68.1072 | 32.1527    |                  2 |                581 |               1226 |                 19 |            0.0113685 |           0.0062191 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.58291   |           5.24229   |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.2888 |  0.0821693 |                 12 |                  1 |               1216 |                599 |            9.33007   |           5.10398   |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm mean manhattan]]
# ['filled 2s split with bandwidth caida 2007'] with [0.00156425026181993]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        68.5996 | 31.5254    |                 16 |                558 |               1212 |                 42 |             0.014019 |          0.00766904 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |             9.49558  |          5.19452    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.6324 |  0.0829876 |                 24 |                  1 |               1204 |                599 |             9.26791  |          5.06997    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm mean chebyshev]]
# ['filled 2s split with bandwidth caida 2007'] with [0.0009661398834952817]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        68.2713 | 32.02      |                  3 |                577 |               1225 |                 23 |            0.0150762 |          0.00824735 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.72657   |          5.32088    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.2888 |  0.0821693 |                 12 |                  1 |               1216 |                599 |            9.55645   |          5.22782    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.053665622713146066]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        32.8228 | 0         |               1228 |                  0 |                  0 |                600 |            0.0308933 |           0.0169001 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 | 0.0820345 |                 10 |                  1 |               1218 |                599 |            9.53535   |           5.21627   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        32.8228 | 0         |               1228 |                  0 |                  0 |                600 |            0.0323267 |           0.0176842 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.00026084265301600656]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.6135    |                 11 |                589 |               1217 |                 11 |            0.0113897 |          0.00623071 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.58619   |          5.24409    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.7965 |  0.0827815 |                 21 |                  1 |               1207 |                599 |            9.34844   |          5.11403    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median manhattan]]
# ['filled 2s split with bandwidth caida 2007'] with [0.0004287035699704206]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.6696 | 32.2365    |                 13 |                578 |               1215 |                 22 |            0.0138037 |          0.00755127 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.50635   |          5.20041    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.7418 |  0.08285   |                 22 |                  1 |               1206 |                599 |            9.32071   |          5.09886    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median chebyshev]]
# ['filled 2s split with bandwidth caida 2007'] with [0.01057188620566455]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        32.8775 | 0         |               1227 |                  0 |                  1 |                600 |            0.0139201 |          0.00761492 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 | 0.0820345 |                 10 |                  1 |               1218 |                599 |            9.53626   |          5.21677    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        32.8775 | 0         |               1227 |                  0 |                  1 |                600 |            0.0209591 |          0.0114656  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm median cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [-0.024384534506589655]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0310512 |           0.0169864 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.57806   |           5.23964   |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.66826   |           5.28898   |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.02159893009553088]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0113859 |          0.00622862 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.43909   |          5.16362    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.53997   |          5.2188     |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean manhattan]]
# ['filled 2s split with bandwidth caida 2007'] with [1.4436031212396625]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        70.5689 | 29.8716    |                 26 |                512 |               1202 |                 88 |            0.0139563 |          0.00763474 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.5341    |          5.21559    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.2495 |  0         |                 32 |                  0 |               1196 |                600 |            8.94366   |          4.89259    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean chebyshev]]
# ['filled 2s split with bandwidth caida 2007'] with [-0.036856093418179955]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0141506 |          0.00774104 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.4834    |          5.18786    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.48403   |          5.1882     |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [-0.0025764909839279433]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0304928 |            0.016681 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.60605   |            5.25495  |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.6502    |            5.27911  |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [-0.01894672130001534]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0113254 |          0.00619549 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.4339    |          5.16077    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.60372   |          5.25367    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median manhattan]]
# ['filled 2s split with bandwidth caida 2007'] with [1.0325137913807163]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        71.2254 | 29.3286    |                 28 |                498 |               1200 |                102 |            0.0140791 |          0.00770191 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.66364   |          5.28645    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.1947 |  0         |                 33 |                  0 |               1195 |                600 |            8.84721   |          4.83983    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median chebyshev]]
# ['filled 2s split with bandwidth caida 2007'] with [-0.036361111429665555]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0140085 |          0.00766331 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.49067   |          5.19183    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.46433   |          5.17743    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool laplacian median cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [1.0579944201014708]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        71.663  | 28.9442    |                 30 |                488 |               1198 |                112 |            0.0302558 |           0.0165513 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.57124   |           5.23591   |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.0853 |  0         |                 35 |                  0 |               1193 |                600 |            8.96896   |           4.90644   |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [-0.00976557813642506]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |             0.011322 |          0.00619367 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |             9.49338  |          5.19331    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |             9.53199  |          5.21444    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean manhattan]]
# ['filled 2s split with bandwidth caida 2007'] with [0.13166374588391794]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        69.5295 | 31.0773    |                  6 |                551 |               1222 |                 49 |            0.0142021 |          0.00776921 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.58788   |          5.24501    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.1794 |  0.0823045 |                 14 |                  1 |               1214 |                599 |            9.21839   |          5.04288    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean chebyshev]]
# ['filled 2s split with bandwidth caida 2007'] with [0.03015206252007252]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0140767 |          0.00770061 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.44262   |          5.16555    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.51699   |          5.20623    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.036024207463455596]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        32.8228 | 0         |               1228 |                  0 |                  0 |                600 |            0.0298951 |           0.016354  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 | 0.0820345 |                 10 |                  1 |               1218 |                599 |            9.6351    |           5.27084   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        32.8228 | 0         |               1228 |                  0 |                  0 |                600 |            0.0318286 |           0.0174117 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.0031751812671682103]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        69.4748 | 30.879     |                 17 |                541 |               1211 |                 59 |             0.011394 |          0.00623305 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |             9.49979  |          5.19682    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.523  |  0.0831255 |                 26 |                  1 |               1202 |                599 |             9.17292  |          5.01801    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median manhattan]]
# ['filled 2s split with bandwidth caida 2007'] with [0.002830961303179662]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        69.1466 | 31.3692    |                  5 |                559 |               1223 |                 41 |            0.0148027 |          0.00809775 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.45858   |          5.17428    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.1794 |  0.0823045 |                 14 |                  1 |               1214 |                599 |            9.24768   |          5.05891    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median chebyshev]]
# ['filled 2s split with bandwidth caida 2007'] with [0.0024039784473449816]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        69.0372 | 31.467     |                  4 |                562 |               1224 |                 38 |            0.0138178 |          0.00755896 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.51237   |          5.2037     |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.2341 |  0.0822368 |                 13 |                  1 |               1215 |                599 |            9.24558   |          5.05776    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo avgpool gaussian median cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [2.9518927571560438e-05]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        32.8775 | 0         |               1227 |                  0 |                  1 |                600 |            0.0312192 |           0.0170784 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 | 0.0820345 |                 10 |                  1 |               1218 |                599 |            9.55229   |           5.22554   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        32.8775 | 0         |               1227 |                  0 |                  1 |                600 |            0.0374033 |           0.0204613 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [-0.03125301648719191]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0113471 |          0.00620736 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.40131   |          5.14295    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.41451   |          5.15017    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean manhattan]]
# ['filled 2s split with bandwidth caida 2007'] with [0.011603635304937165]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0141029 |          0.00771495 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.73951   |          5.32796    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.49478   |          5.19408    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean chebyshev]]
# ['filled 2s split with bandwidth caida 2007'] with [0.03628286915822977]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0153604 |          0.00840282 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.95248   |          5.44446    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.75001   |          5.33371    |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.04057163048052177]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0309298 |             0.01692 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.59768   |             5.25037 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.3982 |  0.0820345 |                 10 |                  1 |               1218 |                599 |            9.54161   |             5.2197  |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[norm convo maxpool laplacian median euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.01732027581938842]
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |    FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+============+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 | 32.8228    |                  0 |                600 |               1228 |                  0 |            0.0114145 |          0.00624427 |
# +----------+----------------+------------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# ...
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |            9.58694   |          5.24449    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.9606 |   0       |                 19 |                  0 |               1209 |                600 |            6.98391   |          3.82052    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool laplacian median cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [-0.010192896652136706]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.1772 |   32.8228 |                  0 |                600 |               1228 |                  0 |            0.0301168 |           0.0164753 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |    0      |                  9 |                  0 |               1219 |                600 |            9.50926   |           5.202     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.5077 |    0      |                  9 |                  0 |               1219 |                600 |            9.72267   |           5.31875   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.21266004778198058]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.6937 |    6.2645 |                 16 |                 81 |               1212 |                519 |            0.0113096 |          0.00618688 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |    0      |                  9 |                  0 |               1219 |                600 |            9.60571   |          5.25477    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.9059 |    0      |                 20 |                  0 |               1208 |                600 |            6.88254   |          3.76507    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean manhattan]]
# ['filled 2s split with bandwidth caida 2007'] with [0.4643717908299065]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.5295 |   6.41422 |                 17 |                 83 |               1211 |                517 |            0.0137262 |          0.00750888 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |            9.48729   |          5.18998    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.8512 |   0       |                 21 |                  0 |               1207 |                600 |            6.78967   |          3.71426    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean chebyshev]]
# ['filled 2s split with bandwidth caida 2007'] with [0.13862844865655527]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.8031 |   5.98291 |                 18 |                 77 |               1210 |                523 |            0.0140111 |          0.00766474 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |            9.51855   |          5.20709    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.7965 |   0       |                 22 |                  0 |               1206 |                600 |            6.64309   |          3.63407    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.005127931553286346]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        91.1926 |   2.74579 |                130 |                 31 |               1098 |                569 |            0.0300705 |             0.01645 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |            9.50633   |             5.2004  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        92.779  |   0       |                132 |                  0 |               1096 |                600 |            5.86763   |             3.20986 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.13423946945943588]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.2013 |   6.91244 |                 16 |                 90 |               1212 |                510 |            0.0115469 |          0.00631666 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |            9.48661   |          5.18961    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.9059 |   0       |                 20 |                  0 |               1208 |                600 |            6.77978   |          3.70885    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median manhattan]]
# ['filled 2s split with bandwidth caida 2007'] with [0.2628857398389225]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.5295 |   6.41422 |                 17 |                 83 |               1211 |                517 |            0.0145667 |          0.00796863 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |            9.53241   |          5.21467    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.8512 |   0       |                 21 |                  0 |               1207 |                600 |            6.69757   |          3.66388    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median chebyshev]]
# ['filled 2s split with bandwidth caida 2007'] with [0.09993355801536564]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.0372 |   7.25745 |                 14 |                 95 |               1214 |                505 |            0.0140734 |          0.00769878 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |            9.51418   |          5.20469    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.9606 |   0       |                 19 |                  0 |               1209 |                600 |            6.98259   |          3.8198     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian median cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.0013979950820526038]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        92.6696 |    8.9955 |                 14 |                120 |               1214 |                480 |            0.0310588 |           0.0169906 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |    0      |                  9 |                  0 |               1219 |                600 |            9.57384   |           5.23733   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.9059 |    0      |                 20 |                  0 |               1208 |                600 |            7.11789   |           3.89381   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
# value1 = results[0][0]
# for value in value1:
#   print(f"variation : [[{value}]]")
#   show_as_table([results[3][0][value]])

# %% [markdown]
# ## tanh convo maxpool gaussian mean varying difference

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[0][0][value]])
# Out:
# variation : [[tanh mean euclidean]]
# ['self made data'] with [0.1234315775621764]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        92.2472 |   10.5618 |                 22 |                 47 |                398 |                423 |           0.00354052 |          0.00397811 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           5.96472    |          6.70193    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.5281 |    0      |                 22 |                  0 |                398 |                470 |           2.40093    |          2.69767    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh mean cosine]]
# ['self made data'] with [0.00531840243457497]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.2584 |   9.09091 |                 20 |                 40 |                400 |                430 |            0.0100076 |           0.0112445 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |            6.09613   |           6.84959   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.7528 |   0       |                 20 |                  0 |                400 |                470 |            2.63919   |           2.96539   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['self made data'] with [0.20549455354747787]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        89.3258 |   13.3183 |                 36 |                 59 |                384 |                411 |           0.00364327 |          0.00409357 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           5.07469    |          5.7019     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        95.9551 |    0      |                 36 |                  0 |                384 |                470 |           3.39354    |          3.81297    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['self made data'] with [0.006785965911091193]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.7079 |   7.67442 |                 23 |                 33 |                397 |                437 |             0.012146 |           0.0136472 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |             5.03183  |           5.65374   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.4157 |   0       |                 23 |                  0 |                397 |                470 |             3.2728   |           3.6773    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[1][0][value]])
# Out:
# variation : [[tanh mean euclidean]]
# ['1s split with '] with [0.1643966881701886]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.71   |   6.99734 |               1097 |                 79 |               1050 |               1416 |             0.014895 |          0.00408978 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |            22.4397   |          6.16138    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        69.8792 |   0       |               1097 |                  0 |               1050 |               1495 |             6.74035  |          1.85073    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh mean cosine]]
# ['1s split with '] with [0.005208810531682644]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        96.2109 |   2.55078 |                 84 |                 54 |               2063 |               1441 |            0.0395708 |           0.0108651 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           22.8955    |           6.28651   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.6936 |   0       |                 84 |                  0 |               2063 |               1495 |           12.8609    |           3.53127   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['1s split with '] with [0.18578968837956888]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        95.6617 |   6.77966 |                  2 |                156 |               2145 |               1339 |            0.0143933 |          0.00395204 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           22.7249    |          6.23968    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.9451 |   0       |                  2 |                  0 |               2145 |               1495 |           14.2387    |          3.90957    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['1s split with '] with [0.006683235451738698]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        95.9088 |    1.2207 |                124 |                 25 |               2023 |               1470 |            0.0403826 |            0.011088 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           22.4075    |            6.15253  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        96.5953 |    0      |                124 |                  0 |               2023 |               1495 |           12.7732    |            3.50719  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[2][0][value]])
# Out:
# variation : [[tanh mean euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.142091088628623]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        90.5908 |   6.07321 |                 99 |                 73 |               1129 |                527 |            0.0134814 |          0.00737493 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           11.0639    |          6.05246    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        94.3654 |   0       |                103 |                  0 |               1125 |                600 |            7.85733   |          4.29832    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.004278850885478134]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        90.372  |   4.65517 |                122 |                 54 |               1106 |                546 |            0.0200937 |           0.0109922 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           11.2672    |           6.16368   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        93.1072 |   0       |                126 |                  0 |               1102 |                600 |            6.8358    |           3.73949   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.2132485559925164]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.6937 |    6.2645 |                 16 |                 81 |               1212 |                519 |            0.0136747 |          0.00748071 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |    0      |                  9 |                  0 |               1219 |                600 |           11.5551    |          6.32115    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.9059 |    0      |                 20 |                  0 |               1208 |                600 |            8.20987   |          4.49118    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.005359314246066622]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        90.4267 |   2.61026 |                146 |                 29 |               1082 |                571 |            0.0229695 |           0.0125654 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           11.2115    |           6.13319   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        91.9037 |   0       |                148 |                  0 |               1080 |                600 |            6.46601   |           3.5372    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %% [markdown]
# ## tanh convo maxpool gaussian median

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[0][0][value]])
# Out:
# variation : [[tanh mean euclidean]]
# ['self made data'] with [0.1234315775621764]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        92.2472 |   10.5618 |                 22 |                 47 |                398 |                423 |           0.00354052 |          0.00397811 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           5.96472    |          6.70193    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.5281 |    0      |                 22 |                  0 |                398 |                470 |           2.40093    |          2.69767    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh mean cosine]]
# ['self made data'] with [0.00531840243457497]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.2584 |   9.09091 |                 20 |                 40 |                400 |                430 |            0.0100076 |           0.0112445 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |            6.09613   |           6.84959   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.7528 |   0       |                 20 |                  0 |                400 |                470 |            2.63919   |           2.96539   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['self made data'] with [0.20549455354747787]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        89.3258 |   13.3183 |                 36 |                 59 |                384 |                411 |           0.00364327 |          0.00409357 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           5.07469    |          5.7019     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        95.9551 |    0      |                 36 |                  0 |                384 |                470 |           3.39354    |          3.81297    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['self made data'] with [0.006785965911091193]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.7079 |   7.67442 |                 23 |                 33 |                397 |                437 |             0.012146 |           0.0136472 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |             5.03183  |           5.65374   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.4157 |   0       |                 23 |                  0 |                397 |                470 |             3.2728   |           3.6773    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[1][0][value]])
# Out:
# variation : [[tanh mean euclidean]]
# ['1s split with '] with [0.1643966881701886]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.71   |   6.99734 |               1097 |                 79 |               1050 |               1416 |             0.014895 |          0.00408978 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |            22.4397   |          6.16138    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        69.8792 |   0       |               1097 |                  0 |               1050 |               1495 |             6.74035  |          1.85073    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh mean cosine]]
# ['1s split with '] with [0.005208810531682644]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        96.2109 |   2.55078 |                 84 |                 54 |               2063 |               1441 |            0.0395708 |           0.0108651 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           22.8955    |           6.28651   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.6936 |   0       |                 84 |                  0 |               2063 |               1495 |           12.8609    |           3.53127   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['1s split with '] with [0.18578968837956888]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        95.6617 |   6.77966 |                  2 |                156 |               2145 |               1339 |            0.0143933 |          0.00395204 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           22.7249    |          6.23968    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.9451 |   0       |                  2 |                  0 |               2145 |               1495 |           14.2387    |          3.90957    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['1s split with '] with [0.006683235451738698]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        95.9088 |    1.2207 |                124 |                 25 |               2023 |               1470 |            0.0403826 |            0.011088 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           22.4075    |            6.15253  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        96.5953 |    0      |                124 |                  0 |               2023 |               1495 |           12.7732    |            3.50719  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[2][0][value]])
# Out:
# variation : [[tanh mean euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.142091088628623]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        90.5908 |   6.07321 |                 99 |                 73 |               1129 |                527 |            0.0134814 |          0.00737493 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           11.0639    |          6.05246    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        94.3654 |   0       |                103 |                  0 |               1125 |                600 |            7.85733   |          4.29832    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.004278850885478134]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        90.372  |   4.65517 |                122 |                 54 |               1106 |                546 |            0.0200937 |           0.0109922 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           11.2672    |           6.16368   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        93.1072 |   0       |                126 |                  0 |               1102 |                600 |            6.8358    |           3.73949   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.2132485559925164]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.6937 |    6.2645 |                 16 |                 81 |               1212 |                519 |            0.0136747 |          0.00748071 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |    0      |                  9 |                  0 |               1219 |                600 |           11.5551    |          6.32115    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.9059 |    0      |                 20 |                  0 |               1208 |                600 |            8.20987   |          4.49118    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.005359314246066622]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        90.4267 |   2.61026 |                146 |                 29 |               1082 |                571 |            0.0229695 |           0.0125654 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           11.2115    |           6.13319   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        91.9037 |   0       |                148 |                  0 |               1080 |                600 |            6.46601   |           3.5372    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
value1 = results[0][0]
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[0][0][value]])
# Out:
# variation : [[tanh mean euclidean]]
# ['self made data'] with [0.1234315775621764]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        92.2472 |   10.5618 |                 22 |                 47 |                398 |                423 |           0.00354052 |          0.00397811 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           5.96472    |          6.70193    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.5281 |    0      |                 22 |                  0 |                398 |                470 |           2.40093    |          2.69767    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh mean cosine]]
# ['self made data'] with [0.00531840243457497]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.2584 |   9.09091 |                 20 |                 40 |                400 |                430 |            0.0100076 |           0.0112445 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |            6.09613   |           6.84959   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.7528 |   0       |                 20 |                  0 |                400 |                470 |            2.63919   |           2.96539   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['self made data'] with [0.20549455354747787]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        89.3258 |   13.3183 |                 36 |                 59 |                384 |                411 |           0.00364327 |          0.00409357 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |    0      |                  1 |                  0 |                419 |                470 |           5.07469    |          5.7019     |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        95.9551 |    0      |                 36 |                  0 |                384 |                470 |           3.39354    |          3.81297    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['self made data'] with [0.006785965911091193]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        93.7079 |   7.67442 |                 23 |                 33 |                397 |                437 |             0.012146 |           0.0136472 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.8876 |   0       |                  1 |                  0 |                419 |                470 |             5.03183  |           5.65374   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.4157 |   0       |                 23 |                  0 |                397 |                470 |             3.2728   |           3.6773    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[1][0][value]])
# Out:
# variation : [[tanh mean euclidean]]
# ['1s split with '] with [0.1643966881701886]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        67.71   |   6.99734 |               1097 |                 79 |               1050 |               1416 |             0.014895 |          0.00408978 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |            22.4397   |          6.16138    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        69.8792 |   0       |               1097 |                  0 |               1050 |               1495 |             6.74035  |          1.85073    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh mean cosine]]
# ['1s split with '] with [0.005208810531682644]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        96.2109 |   2.55078 |                 84 |                 54 |               2063 |               1441 |            0.0395708 |           0.0108651 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           22.8955    |           6.28651   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        97.6936 |   0       |                 84 |                  0 |               2063 |               1495 |           12.8609    |           3.53127   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['1s split with '] with [0.18578968837956888]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        95.6617 |   6.77966 |                  2 |                156 |               2145 |               1339 |            0.0143933 |          0.00395204 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |   0       |                  0 |                  0 |               2147 |               1495 |           22.7249    |          6.23968    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        99.9451 |   0       |                  2 |                  0 |               2145 |               1495 |           14.2387    |          3.90957    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['1s split with '] with [0.006683235451738698]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        95.9088 |    1.2207 |                124 |                 25 |               2023 |               1470 |            0.0403826 |            0.011088 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |       100      |    0      |                  0 |                  0 |               2147 |               1495 |           22.4075    |            6.15253  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        96.5953 |    0      |                124 |                  0 |               2023 |               1495 |           12.7732    |            3.50719  |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
for value in value1:
  print(f"variation : [[{value}]]")
  show_as_table([results[2][0][value]])
# Out:
# variation : [[tanh mean euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.142091088628623]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        90.5908 |   6.07321 |                 99 |                 73 |               1129 |                527 |            0.0134814 |          0.00737493 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           11.0639    |          6.05246    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        94.3654 |   0       |                103 |                  0 |               1125 |                600 |            7.85733   |          4.29832    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.004278850885478134]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        90.372  |   4.65517 |                122 |                 54 |               1106 |                546 |            0.0200937 |           0.0109922 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           11.2672    |           6.16368   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        93.1072 |   0       |                126 |                  0 |               1102 |                600 |            6.8358    |           3.73949   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean euclidean]]
# ['filled 2s split with bandwidth caida 2007'] with [0.2132485559925164]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        94.6937 |    6.2645 |                 16 |                 81 |               1212 |                519 |            0.0136747 |          0.00748071 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |    0      |                  9 |                  0 |               1219 |                600 |           11.5551    |          6.32115    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        98.9059 |    0      |                 20 |                  0 |               1208 |                600 |            8.20987   |          4.49118    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# variation : [[tanh convo maxpool gaussian mean cosine]]
# ['filled 2s split with bandwidth caida 2007'] with [0.005359314246066622]
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Method   |   Accuracy (%) |   FDR (%) |   Attack as Normal |   Normal as Attack |   Attack as Attack |   Normal as Normal |   Execution Time (s) |   Average Time (ms) |
# +==========+================+===========+====================+====================+====================+====================+======================+=====================+
# | SOM      |        90.4267 |   2.61026 |                146 |                 29 |               1082 |                571 |            0.0229695 |           0.0125654 |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | RF       |        99.5077 |   0       |                  9 |                  0 |               1219 |                600 |           11.2115    |           6.13319   |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+
# | Combined |        91.9037 |   0       |                148 |                  0 |               1080 |                600 |            6.46601   |           3.5372    |
# +----------+----------------+-----------+--------------------+--------------------+--------------------+--------------------+----------------------+---------------------+

# %%
show_as_table([value1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-9719a6f1cd25> in <cell line: 1>()
# ----> 1 show_as_table([value1])
#
# <ipython-input-20-404f9a687295> in show_as_table(data)
#       3   table_data = []
#       4   for item in data:
# ----> 5       som_row = item['som_values'][0]['evaluation1']
#       6       rf_row = item['rf_values'][0]['evaluation1']
#       7       combined_row = item['combined_values'][0]['evaluation1']
#
# KeyError: 'som_values'

# %%
# #save results to self_data_only.pkl
# with open('self_data_only.pkl', 'wb') as f:
#     pickle.dump(results, f)

# %% [markdown]
# ## tables

# %%
# final_result = {}

# %%
final_result

# %%
for data in results: # with median 50X50 50 gen tanh normalize convolution laplacian
  show_as_table(data)
final_result['with median 50X50 50 gen tanh normalize convolution laplacian'] = data

# %%
# for data in results: # with median 50X50 50 gen tanh normalize
#   show_as_table(data)
# final_result['with median 50X50 50 gen tanh normalize'] = data

# %%
for data in results: # with mean 50X50 50 gen tanh normalize
  show_as_table(data)

# %%
for data in results: # with mean 30X30 10 gen tanh normalize
  show_as_table(data)

# %%
for data in results: # with mean 30X30 50 gen tanh normalize
  show_as_table(data)

# %%
for data in results: # with mean 10X10 50 gen tanh normalize
  show_as_table(data)

# %%
for data in results: # with mean 100X100 50 gen tanh normalize
  show_as_table(data)

# %%
for data in results: # with mean 100X100 500 gen custom normalize
  show_as_table(data)

# %%
for data in results: # with mean 100 X 100 500 gen customdef normalize convo laplacian
  show_as_table(data)

# %%
for data in results: # with mean 100 X 100 50 gen
  show_as_table(data)

# %%
for data in results: # with mean 100 X 100 500 gen
  show_as_table(data)

# %%
for data in results: # with mean 100 X 100
  show_as_table(data)

# %%
for data in results: # with mean 50 X 50
  show_as_table(data)

# %%
for data in results: # with mean convo laplacian avgpooled
  show_as_table(data)

# %%
for data in results: # with mean convo laplacian maxpooled
  show_as_table(data)

# %%
for data in results: # with mean convo laplacian
  show_as_table(data)

# %%
for data in results: # with median convo laplacian
  show_as_table(data)

# %%
for data in results: # with median convo gaussian
  show_as_table(data)

# %%
for data in results: # with mean convo gaussian
  show_as_table(data)

# %%
result_df = pd.DataFrame(results[0][0]["som_values"][0])
result_df

# %%
df_test = pd.DataFrame(results[0]['som_values'][0][0])
df_test

# %%
# var_1_with_mean_convolution_and_gaussian = results

# %%
results_df = pd.DataFrame(results)
results_df

# %% [markdown]
# ## other

# %%
# make each row of result_df into separate dfs
for i in range(len(results)):
    results[i] = pd.DataFrame(results[i])
    results[i].columns = ['som_values', 'rf_values', 'y_pred_som_and_rf_values']
    # results[i] = results[i].astype(float)
    # print(results[i])
results[0]

# %%
# each column of results[0] into a dataframe
df1 = results[0]['som_values']
df2 = results[0]['rf_values']
df3 = results[0]['y_pred_som_and_rf_values']

# %%
df1[0][0]

# %%
value_pd1 = (df1[0][0])
data_dicts = value_pd1
rows = []

# Iterate over each dictionary and convert to DataFrame row
for data_dict in data_dicts:
    rows.append(pd.DataFrame(data_dict, index=[0]))

# Concatenate all rows into a single DataFrame
df = pd.concat(rows, ignore_index=True)

df

# %%
df

# %%
## printing all the max accuracy rows
value_pd[value_pd['accuracy'] == value_pd['accuracy'].max()]

# %%
get_d_threshold_value_for_max_eval(value_pd)

# %%
## printing all the max accuracy rows
value_pd[value_pd['accuracy'] == value_pd['accuracy'].max()]

# %%
# # #self made data
# # urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/som_data.csv")
# # comments.append("self made data")





# results = []
# iteration = 0
# for url in urls:
#   comment = comments[iteration]
#   if 'without bandwidth' in comment:
#     bandflag = 1
#   else:
#     bandflag = 0
#   print(f"Iteration : {iteration}")

#   df = pd.read_csv(url)

#   # y_pred_som_and_rf = with_som_and_rf(df,comment, bandflag) # without rf modify
#   value = som_with_som_and_rf_actual(df,comment, bandflag) # with rfmodify and working
#   # value = som_with_varying_sigma_and_d_threshold(df)

#   results.append(value)
#   iteration = iteration + 1

# %%
# y_pred_som_and_rf
value_1 = pd.DataFrame(value_pd[0])
value_1

# %%
# results

# %%
# resultant_columns = ['som_values', 'rf_values', 'y_pred_som_and_rf_values']
# resultant_df = pd.DataFrame(results,columns=resultant_columns)

# %%
# resultant_df_som = resultant_df['som_values']
# resultant_df_rf = resultant_df['rf_values']
# resultant_df_som_and_rf = resultant_df['y_pred_som_and_rf_values']

# %%
# resultant_df_som

# %%
# resultant_df_rf

# %%
# resultant_columns = ['com','accuracy', 'attack_as_normal', 'normal_as_attack', 'attack_as_attack', 'normal_as_normal']
# resultant_df_som = pd.DataFrame(resultant_df_som,columns=resultant_columns)

# %%
# # #self made data
# # urls.append("https://raw.githubusercontent.com/sudomaster00081/MscProj/main/Implimentation/som_data.csv")
# # comments.append("self made data")





# results = []
# iteration = 0
# for url in urls:
#   comment = comments[iteration]
#   if 'without bandwidth' in comment:
#     bandflag = 1
#   else:
#     bandflag = 0
#   print(f"Iteration : {iteration}")

#   df = pd.read_csv(url)

#   # y_pred_som_and_rf = with_som_and_rf(df,comment, bandflag) # without rf modify
#   value = som_with_som_and_rf_actual(df,comment, bandflag) # with rfmodify and working
#   # value = som_with_varying_sigma_and_d_threshold(df)

#   results.append(value)
#   iteration = iteration + 1

# %%
# resultant_df_som

# %%
# y_pred_som_and_rf

# %%
# result
