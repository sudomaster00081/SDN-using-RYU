# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import time
import datetime
import warnings
import re
import json
import pickle
import random
import math

# %%
print("combine datasets")
# Out:
# combine datasets

# %%
# read data 1

df1 = pd.read_csv("data1.csv")
df1
# Out:
#                                  Display current time.                time \n
# 0    Run iperf test between h1 and h2 using UDP pro...   h1 iperfudp -c h2 \n
# 1                   Start a TCP traffic from h1 to h2.      h1 iperf -c h2 \n
# 2        Show me the available commands for switch s1.             s1 help \n
# 3                Start an iperf test between h1 and h2      h1 iperf -c h2 \n
# 4                            Display the current time.                time \n
# ..                                                 ...                    ...
# 257                  Start an iperf test from h1 to h2      h1 iperf -c h2 \n
# 258              Start a terminal on h1 for 5 minutes.       xterm h1 -t 5 \n
# 259             Show the available network interfaces.               intfs \n
# 260    Check the status of the link between h1 and h2.          link h1 h2 \n
# 261          How to start a terminal for h2 without X?            gterm h2 \n
#
# [262 rows x 2 columns]

# %%
# read data 2

df2 = pd.read_csv("data2.csv")
df2
# Out:
#                                   Display current time.  \
# 0     Run iperf test between h1 and h2 using UDP pro...
# 1                    Start a TCP traffic from h1 to h2.
# 2         Show me the available commands for switch s1.
# 3                 Start an iperf test between h1 and h2
# 4                             Display the current time.
# ...                                                 ...
# 1106              What are the interfaces on all nodes?
# 1107        Start a ping from h1 to h2 with 10 packets.
# 1108  Run an Iperf test from h1 to h2 with 1000 pack...
# 1109  Start a UDP iperf test from h1 to h2 with 1000...
# 1110                Start an interactive terminal on h1
#
#                             time \n
# 0              h1 iperfudp -c h2 \n
# 1                 h1 iperf -c h2 \n
# 2                        s1 help \n
# 3                 h1 iperf -c h2 \n
# 4                           time \n
# ...                             ...
# ...

# %%
# add columns as input and output for dfs
df1_with_heading = df1
df1_with_heading.columns = ["input", "output"]
df1_with_heading

df2_with_heading = df2
df2_with_heading.columns = ["input", "output"]
df2_with_heading
# Out:
#                                                   input  \
# 0     Run iperf test between h1 and h2 using UDP pro...
# 1                    Start a TCP traffic from h1 to h2.
# 2         Show me the available commands for switch s1.
# 3                 Start an iperf test between h1 and h2
# 4                             Display the current time.
# ...                                                 ...
# 1106              What are the interfaces on all nodes?
# 1107        Start a ping from h1 to h2 with 10 packets.
# 1108  Run an Iperf test from h1 to h2 with 1000 pack...
# 1109  Start a UDP iperf test from h1 to h2 with 1000...
# 1110                Start an interactive terminal on h1
#
#                              output
# 0              h1 iperfudp -c h2 \n
# 1                 h1 iperf -c h2 \n
# 2                        s1 help \n
# 3                 h1 iperf -c h2 \n
# 4                           time \n
# ...                             ...
# ...

# %%
#check if both the dataframe has same columns, if true append them
if list(df1_with_heading.columns) == list(df2_with_heading.columns):
  df_combined = pd.concat([df1_with_heading, df2_with_heading], ignore_index=True)
df_combined
# Out:
#                                                   input  \
# 0     Run iperf test between h1 and h2 using UDP pro...
# 1                    Start a TCP traffic from h1 to h2.
# 2         Show me the available commands for switch s1.
# 3                 Start an iperf test between h1 and h2
# 4                             Display the current time.
# ...                                                 ...
# 1368              What are the interfaces on all nodes?
# 1369        Start a ping from h1 to h2 with 10 packets.
# 1370  Run an Iperf test from h1 to h2 with 1000 pack...
# 1371  Start a UDP iperf test from h1 to h2 with 1000...
# 1372                Start an interactive terminal on h1
#
#                              output
# 0              h1 iperfudp -c h2 \n
# 1                 h1 iperf -c h2 \n
# 2                        s1 help \n
# 3                 h1 iperf -c h2 \n
# 4                           time \n
# ...                             ...
# ...

# %%
# remove duplicates in combined df
df_combined.drop_duplicates(subset=["input", "output"], keep="first", inplace=True)
df_combined
# Out:
#                                                   input  \
# 0     Run iperf test between h1 and h2 using UDP pro...
# 1                    Start a TCP traffic from h1 to h2.
# 2         Show me the available commands for switch s1.
# 3                 Start an iperf test between h1 and h2
# 4                             Display the current time.
# ...                                                 ...
# 1365         Send a ping to h3 from h2 with 10 packets.
# 1366      Display the available commands for switch s1.
# 1367                      Run a command on the node h1.
# 1368              What are the interfaces on all nodes?
# 1370  Run an Iperf test from h1 to h2 with 1000 pack...
#
#                           output
# 0           h1 iperfudp -c h2 \n
# 1              h1 iperf -c h2 \n
# 2                     s1 help \n
# 3              h1 iperf -c h2 \n
# 4                        time \n
# ...                          ...
# 1365         h2 ping -c 10 h3 \n
# ...

# %%
df_combined.shape
# Out:
# (832, 2)
